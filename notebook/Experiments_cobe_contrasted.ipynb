# %%
MAX_NUM_THREADS = 4

import ctypes
mkl_rt = ctypes.CDLL('libmkl_rt.so')
#print(mkl_rt.mkl_get_max_threads())
mkl_get_max_threads = mkl_rt.mkl_get_max_threads
def mkl_set_num_threads(cores):
    mkl_rt.mkl_set_num_threads(ctypes.byref(ctypes.c_int(cores)))

mkl_set_num_threads(MAX_NUM_THREADS)
print(f'Number of threads was limited to {mkl_get_max_threads()}.')
# Out:
# Number of threads was limited to 4.

# %%
import os
import time
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy_tools
import loaders.eth80 as eth80
import loaders.smni_eeg as smni_eeg

from experiment_tools import temporal_sscal
from experiment_tools import kmeans_gmm_clustering_experiment
from experiment_tools import hac_clustering_experiment

import cluster.cobe_contrasting

#from sklearn.metrics import accuracy_score

#from gtcd import reshape
#from computational_utilities import reshape



#from cluster.gica_contrasting import GICAContrast
#from cluster.gtcd_contrasting import GLROContrast
#from cluster.gtcd_contrasting import GTLDContrast

#from sklearn.cluster import AgglomerativeClustering
#from sklearn.cluster import KMeans
#from sklearn.mixture import GaussianMixture as GMM

# clustering performance measures
#from sklearn.metrics import fowlkes_mallows_score
#from sklearn.metrics import adjusted_rand_score
#from sklearn.metrics import normalized_mutual_info_score
#from sklearn.metrics import adjusted_mutual_info_score

#from sklearn.metrics import pairwise_distances

# %%
data_eth80_dirname = '../data/eth80/'
data_smni_dirname = '../data/eeg_smni/'

# %%
# load ETH80
data_eth80_path = os.path.join(data_eth80_dirname, 'eth80-cropped-close128')

image_shape = 32
Nclasses, Nobjects = 8, 10
Npixels = int(round(image_shape**2))

data, labels, classes = eth80.eth80_dataset(data_eth80_path, image_shape)
classes_reverse_dict = dict((y, x) for x, y in classes.items())
Nsamples, Nangles, _, _, Ncolors = data.shape
data = numpy_tools.reshape_np(data, [Nangles, -1, Ncolors], order='F', use_batch=True)
permutation = [0, 2, 1, 3]
data = np.transpose(data, permutation)

n = [Npixels, Nangles, Ncolors]

eth80_dataset = {
    'data': data,
    'n': n,
    'labels': labels,
    'classes': classes,
    'classes_reverse_dict': classes_reverse_dict
}

# %%
# load SMNI EEG
data_smni_path = os.path.join(data_smni_dirname, 'smni_eeg_processed.npz')
df = np.load(data_smni_path)
data, labels = df['data'], df['labels']

Nsubjects, Nchannels, Ntime, Nconditions = data.shape
permutation = [0, 2, 1, 3]
data = np.transpose(data, permutation)
n = [Ntime, Nchannels, Nconditions]

smni_dataset = {
    'data': data,
    'n': n,
    'labels': labels
}

# %%
datasets = {
    'eth80': eth80_dataset,
    'smni': smni_dataset
}
dataset_names = list(datasets.keys())

# %% [markdown]
# ## Clustering with COBE contrast

# %%
save_model_dirname = '../models/clustering/cobe/'
save_filename_base = 'COBE_contrasted'
os.makedirs(save_model_dirname, exist_ok=True)

Ntrials = 20
Ntrials_cobe = 10
np_random_seed = 720
np.random.seed(np_random_seed)
random_states = np.random.randint(1, 1000, Ntrials_cobe)

commonRanks = 1+np.arange(5)

# %%
times = np.zeros([len(commonRanks), Ntrials])

for i in range(len(dataset_names)):
    dataset_name = dataset_names[i]
    print(f'\t\t\t {dataset_name}')
    n = datasets[dataset_name]['n']
    T = numpy_tools.reshape_np(
        datasets[dataset_name]['data'],
        [n[0], -1],
        use_batch=True
    ).astype(np.float32)
    labels = datasets[dataset_name]['labels']
    n_clusters = len(np.unique(labels))
    for k_comr in range(len(commonRanks)):
        commonRank = commonRanks[k_comr]
        print(f'\t COBE: crank={commonRank}')
        for k_trial in range(Ntrials_cobe):
            contrasting = cluster.cobe_contrasting.COBEContrast(
                commonRank,
                shapeObject=[n[0], int(np.prod(n[1:]))],
                maxitnum=100,
                epsilon=1e-5,
                random_state=random_states[k_trial]
            )
            t1 = time.process_time()
            _, inform = contrasting.fit_transform(T, commonRank)
            t2 = time.process_time()
            times[k_comr, k_trial] = t2-t1
            save_filename = (
                f'{save_filename_base}_dataset={dataset_name}_'
                f'crank={commonRank}_trial={k_trial}'
            )
            np.savez_compressed(
                os.path.join(save_model_dirname, f'support_{save_filename}'),
                inform=inform,
                times=times,
                random_states=random_states,
                dataset_names=dataset_names
            )
            contrasting.saveParameters(
                os.path.join(save_model_dirname, f'{save_filename}')
            )
            print(
                f'{commonRank}: t={times[k_comr, k_trial]:.3e}, '
                f'fval={inform["fval"][-1]:.3e}'
            )
# Out:
# 			 eth80
# 	 COBE: crank=1
# 1: t=1.033e+01, fval=9.356e-05
# 1: t=1.097e+01, fval=9.259e-04
# 1: t=1.028e+01, fval=6.458e-03
# 1: t=9.778e+00, fval=3.387e-03
# 1: t=1.419e+01, fval=1.196e-04
# 1: t=1.223e+01, fval=4.178e-03
# 1: t=1.116e+01, fval=8.077e-04
# 1: t=1.096e+01, fval=1.930e-03
# 1: t=1.216e+01, fval=2.629e-03
# 1: t=1.218e+01, fval=8.210e-03
# 	 COBE: crank=2
# 2: t=3.797e+01, fval=2.774e-03
# 2: t=3.771e+01, fval=8.845e-04
# 2: t=3.922e+01, fval=2.079e-03
# 2: t=3.827e+01, fval=3.594e-03
# 2: t=3.367e+01, fval=6.691e-04
# 2: t=4.309e+01, fval=1.998e-03
# 2: t=3.353e+01, fval=6.397e-04
# 2: t=3.622e+01, fval=5.502e-03
# 2: t=3.571e+01, fval=1.254e-03
# 2: t=3.842e+01, fval=6.125e-04
# 	 COBE: crank=3
# 3: t=5.109e+01, fval=7.976e-04
# 3: t=4.436e+01, fval=2.667e-03
# 3: t=4.653e+01, fval=2.756e-03
# 3: t=4.500e+01, fval=1.601e-03
# 3: t=4.161e+01, fval=4.668e-04
# 3: t=4.514e+01, fval=8.147e-03
# 3: t=4.301e+01, fval=1.035e-03
# 3: t=4.453e+01, fval=9.618e-04
# 3: t=4.315e+01, fval=4.262e-03
# 3: t=4.694e+01, fval=1.112e-03
# 	 COBE: crank=4
# 4: t=5.870e+01, fval=2.719e-03
# 4: t=4.897e+01, fval=2.077e-03
# 4: t=5.326e+01, fval=2.087e-03
# 4: t=5.270e+01, fval=1.190e-03
# 4: t=5.436e+01, fval=3.767e-03
# 4: t=5.314e+01, fval=1.857e-03
# 4: t=5.336e+01, fval=1.715e-03
# 4: t=5.796e+01, fval=1.184e-03
# 4: t=4.888e+01, fval=1.284e-03
# 4: t=5.699e+01, fval=4.046e-03
# 	 COBE: crank=5
# 5: t=6.100e+01, fval=1.290e-03
# 5: t=6.393e+01, fval=9.680e-04
# 5: t=6.383e+01, fval=8.053e-03
# 5: t=6.380e+01, fval=1.598e-03
# 5: t=6.690e+01, fval=3.824e-03
# 5: t=5.917e+01, fval=1.374e-02
# 5: t=6.110e+01, fval=6.528e-04
# 5: t=5.575e+01, fval=7.981e-04
# 5: t=5.659e+01, fval=1.658e-03
# 5: t=6.040e+01, fval=1.092e-03
# 			 smni
# 	 COBE: crank=1
# 1: t=5.017e+00, fval=5.244e-03
# 1: t=5.227e+00, fval=4.182e-03
# 1: t=4.384e+00, fval=3.400e-03
# 1: t=4.785e+00, fval=3.662e-03
# 1: t=4.601e+00, fval=3.505e-03
# 1: t=4.731e+00, fval=4.060e-03
# 1: t=4.826e+00, fval=1.722e-03
# 1: t=4.711e+00, fval=3.485e-03
# 1: t=4.292e+00, fval=4.547e-03
# 1: t=4.573e+00, fval=3.424e-03
# 	 COBE: crank=2
# 2: t=1.571e+01, fval=7.063e-03
# 2: t=1.508e+01, fval=4.605e-03
# 2: t=1.500e+01, fval=6.168e-03
# 2: t=1.496e+01, fval=8.071e-03
# 2: t=1.564e+01, fval=6.889e-03
# 2: t=1.403e+01, fval=5.894e-03
# 2: t=1.569e+01, fval=4.821e-03
# 2: t=1.560e+01, fval=5.152e-03
# 2: t=1.684e+01, fval=4.423e-03
# 2: t=1.544e+01, fval=5.799e-03
# 	 COBE: crank=3
# 3: t=2.264e+01, fval=6.451e-03
# 3: t=1.922e+01, fval=7.034e-03
# 3: t=1.844e+01, fval=8.619e-03
# 3: t=2.020e+01, fval=5.404e-03
# 3: t=2.120e+01, fval=6.930e-03
# 3: t=1.819e+01, fval=7.379e-03
# 3: t=1.850e+01, fval=6.304e-03
# 3: t=1.856e+01, fval=6.383e-03
# 3: t=1.797e+01, fval=7.759e-03
# 3: t=2.109e+01, fval=7.201e-03
# 	 COBE: crank=4
# 4: t=2.776e+01, fval=8.230e-03
# 4: t=2.211e+01, fval=6.238e-03
# 4: t=2.097e+01, fval=9.347e-03
# 4: t=2.095e+01, fval=8.234e-03
# 4: t=2.064e+01, fval=6.993e-03
# 4: t=2.155e+01, fval=7.809e-03
# 4: t=2.156e+01, fval=9.439e-03
# 4: t=2.095e+01, fval=9.017e-03
# 4: t=2.157e+01, fval=1.020e-02
# 4: t=2.142e+01, fval=7.791e-03
# 	 COBE: crank=5
# 5: t=2.702e+01, fval=7.899e-03
# 5: t=2.435e+01, fval=1.028e-02
# 5: t=2.429e+01, fval=1.108e-02
# 5: t=2.430e+01, fval=6.937e-03
# 5: t=2.982e+01, fval=9.354e-03
# 5: t=2.743e+01, fval=8.068e-03
# 5: t=2.427e+01, fval=9.667e-03
# 5: t=2.508e+01, fval=9.473e-03
# 5: t=2.405e+01, fval=1.016e-02
# 5: t=2.439e+01, fval=1.066e-02

# %%
model_dirname = '../models/clustering/cobe/'
model_filename_base = 'COBE_contrasted'

save_results_dirname = '../results/clustering/'
os.makedirs(save_results_dirname, exist_ok=True)

save_results_filename_ac = 'cobe_contrasted_ac'
save_results_filename_kg = 'cobe_contrasted_kg'

Ntrials = 20
Ntrials_cobe = 10
np_random_seed = 720
   
def preprocess_cobe(dataset, **kwargs):
    assert 'commonRank' in kwargs
    commonRank = kwargs['commonRank']
    assert 'model_path' in kwargs
    model_path = kwargs['model_path']
    if 'sscal' in kwargs:
        sscal = kwargs['sscal']
    else:
        sscal = False
    n = dataset['n']
    contrasting = cluster.cobe_contrasting.COBEContrast(
        commonRank=commonRank,
        shapeObject=[n[0], int(np.prod(n[1:]))],
        maxitnum=100,
        epsilon=1e-5
    )
    contrasting.loadParameters(model_path)
    T = contrasting._transform_fun(dataset['data'].copy())
    if sscal:
        T = T - np.mean(T, axis=1, keepdims=True)
        T /= np.std(T, axis=1, keepdims=True, ddof=1)
    return T, dataset['labels']

result_ac, result_kg = [], []
affinity_names_old, linkage_old, dataset_names_old, n_clusters_old = None, None, None, None
for k_comr in range(len(commonRanks)):
    commonRank = commonRanks[k_comr]
    print(f'\t COBE: crank={commonRank}')
    result_ac_rank, result_kg_rank = [], []
    for k_trial in range(Ntrials_cobe):
        model_path = lambda dataset_name: (
            f'{save_filename_base}_dataset={dataset_name}_'
            f'crank={commonRank}_trial={k_trial}.npz'
        )
        preprocess = {
            'eth80': lambda x: preprocess_cobe(
                x,
                commonRank=commonRank,
                model_path=os.path.join(model_dirname, model_path('eth80'))
            ),
            'smni': lambda x: preprocess_cobe(
                x,
                commonRank=commonRank,
                model_path=os.path.join(model_dirname, model_path('smni')),
                sscal=True
            )
        }
        result, affinity_names, linkage, dataset_names, n_clusters, df = hac_clustering_experiment(
            datasets,
            save_results_path=None,#save_results_path,
            preprocess=preprocess,
            verbose=True,
            return_datasets=True
        )
        if not ((k_comr == 0) and (k_trial == 0)):
            assert np.all([dataset_names[l] == dataset_names_old[l] for l in range(len(datasets))])
        dataset_names_old = dataset_names
        result_ac_rank.append(result)

        result, dataset_names, random_states, clust_alg_names, n_clusters = (
            kmeans_gmm_clustering_experiment(
                df,#datasets,
                save_results_path=None,#save_results_path,
                preprocess=None,#preprocess,
                Ntrials=Ntrials,
                np_random_seed=np_random_seed,
                verbose=True
            )
        )
        assert dataset_names == dataset_names_old
        if not ((k_comr == 0) and (k_trial == 0)):
            assert np.all([random_states_old[l] == random_states[l] for l in range(Ntrials)])
        random_states_old = random_states
        result_kg_rank.append(result)
        np.savez_compressed(
            'cobe_contrasted_clustering_temp',
            result_ac=result_ac,
            result_kg=result_kg,
            result_ac_rank=result_ac_rank,
            result_kg_rank=result_kg_rank
        )
    result_ac.append(result_ac_rank)
    result_kg.append(result_kg_rank)
result_ac, result_kg = np.array(result_ac), np.array(result_kg)
np.savez_compressed(
    'cobe_contrasted_clustering',
    result_ac=result_ac,
    result_kg=result_kg,
    random_states=random_states,
    clust_alg_names=clust_alg_names,
    Ntrials=Ntrials,
    Ntrials_cobe=Ntrials_cobe,
    np_random_seed=np_random_seed,
    affinity_names=affinity_names,
    linkage=linkage,
    dataset_names=dataset_names
)
# Out:
# 	 COBE: crank=1
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.441 AMI=0.648 FMI=0.533
# 	 Linkage: average
# ARI=0.435 AMI=0.677 FMI=0.546
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.521 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.436 AMI=0.659 FMI=0.538
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.383 AMI=0.587 FMI=0.495
# 	 Linkage: average
# ARI=0.299 AMI=0.551 FMI=0.461
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.497 AMI=0.639 FMI=0.562
# 	 Linkage: average
# ARI=0.514 AMI=0.711 FMI=0.595
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.383 AMI=0.587 FMI=0.495
# 	 Linkage: average
# ARI=0.299 AMI=0.551 FMI=0.461
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.012 AMI=-0.007 FMI=0.610
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.036 AMI=0.042 FMI=0.535
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.036 AMI=0.042 FMI=0.535
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.029 AMI=0.034 FMI=0.531
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.036 AMI=0.042 FMI=0.535
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.036 AMI=0.042 FMI=0.535
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.437/0.550/0.551/0.669
# AMI=0.614/0.698/0.701/0.756
# FMI=0.530/0.611/0.611/0.707
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.253/0.211/0.597
# AMI=0.000/0.331/0.303/0.717
# FMI=0.000/0.286/0.251/0.644
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.148/0.182/0.187/0.220
# AMI=0.100/0.113/0.114/0.141
# FMI=0.591/0.617/0.620/0.635
# 	 GMM min/mean/median/max
# ARI=-0.008/0.151/0.175/0.206
# AMI=-0.007/0.100/0.117/0.140
# FMI=0.515/0.597/0.607/0.624
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.325 AMI=0.536 FMI=0.430
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.454 AMI=0.665 FMI=0.548
# 	 Linkage: average
# ARI=0.378 AMI=0.650 FMI=0.527
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.428 AMI=0.654 FMI=0.534
# 	 Linkage: average
# ARI=0.396 AMI=0.666 FMI=0.546
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.392 AMI=0.632 FMI=0.504
# 	 Linkage: average
# ARI=0.435 AMI=0.710 FMI=0.566
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.403 AMI=0.613 FMI=0.503
# 	 Linkage: average
# ARI=0.510 AMI=0.740 FMI=0.610
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.109 AMI=0.066 FMI=0.577
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.051 AMI=0.017 FMI=0.574
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.051 AMI=0.017 FMI=0.574
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.026 AMI=0.004 FMI=0.577
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.051 AMI=0.017 FMI=0.574
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.051 AMI=0.017 FMI=0.574
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.401/0.561/0.573/0.651
# AMI=0.609/0.723/0.727/0.770
# FMI=0.494/0.626/0.635/0.695
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.237/0.000/0.577
# AMI=0.000/0.312/0.000/0.720
# FMI=0.000/0.267/0.000/0.632
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.135/0.168/0.148/0.205
# AMI=0.092/0.111/0.100/0.135
# FMI=0.584/0.604/0.591/0.629
# 	 GMM min/mean/median/max
# ARI=0.089/0.167/0.174/0.190
# AMI=0.061/0.108/0.108/0.126
# FMI=0.560/0.605/0.610/0.624
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.395 AMI=0.597 FMI=0.491
# 	 Linkage: average
# ARI=0.572 AMI=0.792 FMI=0.660
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.414 AMI=0.647 FMI=0.529
# 	 Linkage: average
# ARI=0.534 AMI=0.763 FMI=0.637
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.276 AMI=0.534 FMI=0.444
# 	 Linkage: average
# ARI=0.024 AMI=0.151 FMI=0.298
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.448 AMI=0.610 FMI=0.531
# 	 Linkage: average
# ARI=0.404 AMI=0.633 FMI=0.523
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.253 AMI=0.480 FMI=0.425
# 	 Linkage: average
# ARI=0.024 AMI=0.151 FMI=0.298
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.032 AMI=0.037 FMI=0.583
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.032 AMI=0.037 FMI=0.583
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.031 AMI=0.008 FMI=0.551
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.032 AMI=0.037 FMI=0.583
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.032 AMI=0.037 FMI=0.583
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.444/0.549/0.567/0.651
# AMI=0.625/0.702/0.704/0.761
# FMI=0.526/0.611/0.621/0.691
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.257/0.186/0.631
# AMI=0.000/0.341/0.296/0.758
# FMI=0.000/0.293/0.241/0.683
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.007/0.001/-0.002/0.018
# AMI=-0.006/0.000/-0.000/0.014
# FMI=0.511/0.517/0.517/0.526
# 	 GMM min/mean/median/max
# ARI=-0.008/0.074/0.085/0.162
# AMI=-0.006/0.076/0.080/0.160
# FMI=0.511/0.559/0.567/0.602
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.441 AMI=0.648 FMI=0.533
# 	 Linkage: average
# ARI=0.435 AMI=0.677 FMI=0.546
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.521 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.436 AMI=0.659 FMI=0.538
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.383 AMI=0.587 FMI=0.495
# 	 Linkage: average
# ARI=0.299 AMI=0.551 FMI=0.461
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.497 AMI=0.639 FMI=0.562
# 	 Linkage: average
# ARI=0.514 AMI=0.711 FMI=0.595
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.383 AMI=0.587 FMI=0.495
# 	 Linkage: average
# ARI=0.299 AMI=0.551 FMI=0.461
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.198 AMI=0.117 FMI=0.645
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.021 AMI=0.006 FMI=0.534
# 	 Linkage: average
# ARI=-0.035 AMI=0.044 FMI=0.683
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.021 AMI=0.006 FMI=0.534
# 	 Linkage: average
# ARI=-0.042 AMI=0.060 FMI=0.669
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.119 AMI=0.066 FMI=0.590
# 	 Linkage: average
# ARI=-0.026 AMI=0.026 FMI=0.698
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.021 AMI=0.006 FMI=0.534
# 	 Linkage: average
# ARI=-0.042 AMI=0.060 FMI=0.669
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.021 AMI=0.006 FMI=0.534
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.451/0.552/0.561/0.669
# AMI=0.622/0.703/0.712/0.756
# FMI=0.530/0.613/0.620/0.707
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.281/0.425/0.611
# AMI=0.000/0.367/0.610/0.753
# FMI=0.000/0.317/0.506/0.669
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.173/0.185/0.188/0.205
# AMI=0.105/0.115/0.117/0.135
# FMI=0.609/0.619/0.620/0.629
# 	 GMM min/mean/median/max
# ARI=0.162/0.184/0.188/0.205
# AMI=0.108/0.118/0.117/0.135
# FMI=0.599/0.615/0.616/0.633
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.395 AMI=0.597 FMI=0.491
# 	 Linkage: average
# ARI=0.389 AMI=0.679 FMI=0.540
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.439 AMI=0.635 FMI=0.535
# 	 Linkage: average
# ARI=0.534 AMI=0.763 FMI=0.637
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.253 AMI=0.480 FMI=0.425
# 	 Linkage: average
# ARI=0.082 AMI=0.286 FMI=0.350
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.464 AMI=0.624 FMI=0.545
# 	 Linkage: average
# ARI=0.408 AMI=0.640 FMI=0.526
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.253 AMI=0.480 FMI=0.425
# 	 Linkage: average
# ARI=0.092 AMI=0.313 FMI=0.351
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.071 AMI=0.026 FMI=0.614
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.059 AMI=0.021 FMI=0.581
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.059 AMI=0.021 FMI=0.581
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.038 AMI=0.008 FMI=0.584
# 	 Linkage: average
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.059 AMI=0.021 FMI=0.581
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.059 AMI=0.021 FMI=0.581
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.375/0.536/0.565/0.639
# AMI=0.573/0.689/0.705/0.756
# FMI=0.462/0.599/0.620/0.680
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.281/0.418/0.631
# AMI=0.000/0.372/0.610/0.758
# FMI=0.000/0.320/0.515/0.683
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.160/0.188/0.188/0.203
# AMI=0.099/0.118/0.117/0.127
# FMI=0.599/0.620/0.620/0.629
# 	 GMM min/mean/median/max
# ARI=-0.004/0.161/0.175/0.220
# AMI=-0.006/0.109/0.112/0.141
# FMI=0.520/0.602/0.609/0.635
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.441 AMI=0.648 FMI=0.533
# 	 Linkage: average
# ARI=0.455 AMI=0.683 FMI=0.556
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.521 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.436 AMI=0.659 FMI=0.538
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.164 AMI=0.432 FMI=0.370
# 	 Linkage: average
# ARI=0.102 AMI=0.317 FMI=0.348
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.435 AMI=0.598 FMI=0.516
# 	 Linkage: average
# ARI=0.404 AMI=0.633 FMI=0.523
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.164 AMI=0.432 FMI=0.370
# 	 Linkage: average
# ARI=0.102 AMI=0.317 FMI=0.348
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.162 AMI=0.108 FMI=0.599
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.025 AMI=0.060 FMI=0.544
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.025 AMI=0.060 FMI=0.544
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.006 AMI=-0.005 FMI=0.578
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.025 AMI=0.060 FMI=0.544
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.025 AMI=0.060 FMI=0.544
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.421/0.543/0.542/0.669
# AMI=0.601/0.689/0.695/0.756
# FMI=0.506/0.604/0.600/0.707
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.204/0.000/0.609
# AMI=0.000/0.264/0.000/0.735
# FMI=0.000/0.230/0.000/0.663
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.111/0.173/0.175/0.202
# AMI=0.078/0.109/0.112/0.124
# FMI=0.571/0.611/0.612/0.633
# 	 GMM min/mean/median/max
# ARI=-0.003/0.123/0.129/0.205
# AMI=-0.005/0.081/0.089/0.135
# FMI=0.517/0.581/0.581/0.626
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.439 AMI=0.644 FMI=0.535
# 	 Linkage: average
# ARI=0.419 AMI=0.650 FMI=0.534
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.521 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.400 AMI=0.645 FMI=0.523
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.574 AMI=0.724 FMI=0.631
# 	 Linkage: average
# ARI=0.366 AMI=0.572 FMI=0.488
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.442 AMI=0.584 FMI=0.519
# 	 Linkage: average
# ARI=0.478 AMI=0.663 FMI=0.560
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.574 AMI=0.724 FMI=0.631
# 	 Linkage: average
# ARI=0.366 AMI=0.572 FMI=0.488
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.238 AMI=0.166 FMI=0.637
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.238 AMI=0.166 FMI=0.637
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.070 AMI=0.058 FMI=0.549
# 	 Linkage: average
# ARI=-0.035 AMI=0.044 FMI=0.683
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.238 AMI=0.166 FMI=0.637
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.238 AMI=0.166 FMI=0.637
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.427/0.537/0.539/0.667
# AMI=0.622/0.691/0.699/0.764
# FMI=0.508/0.600/0.602/0.706
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.277/0.425/0.655
# AMI=0.000/0.365/0.610/0.746
# FMI=0.000/0.315/0.505/0.695
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.148/0.195/0.203/0.204
# AMI=0.100/0.124/0.127/0.131
# FMI=0.591/0.623/0.626/0.629
# 	 GMM min/mean/median/max
# ARI=-0.004/0.142/0.154/0.205
# AMI=-0.006/0.095/0.102/0.135
# FMI=0.515/0.590/0.595/0.626
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.434 AMI=0.641 FMI=0.530
# 	 Linkage: average
# ARI=0.419 AMI=0.650 FMI=0.534
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.439 AMI=0.635 FMI=0.535
# 	 Linkage: average
# ARI=0.400 AMI=0.645 FMI=0.523
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.574 AMI=0.724 FMI=0.631
# 	 Linkage: average
# ARI=0.393 AMI=0.587 FMI=0.501
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.442 AMI=0.584 FMI=0.519
# 	 Linkage: average
# ARI=0.496 AMI=0.644 FMI=0.566
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.574 AMI=0.724 FMI=0.631
# 	 Linkage: average
# ARI=0.393 AMI=0.587 FMI=0.501
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.020 AMI=-0.001 FMI=0.584
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.027 AMI=0.033 FMI=0.572
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.027 AMI=0.033 FMI=0.572
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.020 AMI=0.001 FMI=0.560
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.027 AMI=0.033 FMI=0.572
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.027 AMI=0.033 FMI=0.572
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.427/0.529/0.525/0.667
# AMI=0.622/0.679/0.672/0.764
# FMI=0.508/0.592/0.586/0.706
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.324/0.447/0.655
# AMI=0.000/0.429/0.617/0.746
# FMI=0.000/0.369/0.523/0.695
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.173/0.190/0.188/0.203
# AMI=0.105/0.119/0.117/0.127
# FMI=0.615/0.622/0.620/0.629
# 	 GMM min/mean/median/max
# ARI=-0.004/0.153/0.181/0.205
# AMI=-0.006/0.101/0.114/0.135
# FMI=0.517/0.599/0.615/0.629
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.390 AMI=0.549 FMI=0.475
# 	 Linkage: average
# ARI=0.419 AMI=0.650 FMI=0.534
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.417 AMI=0.596 FMI=0.516
# 	 Linkage: average
# ARI=0.385 AMI=0.635 FMI=0.518
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.355 AMI=0.587 FMI=0.471
# 	 Linkage: average
# ARI=0.317 AMI=0.559 FMI=0.467
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.286 AMI=0.509 FMI=0.405
# 	 Linkage: average
# ARI=0.401 AMI=0.619 FMI=0.506
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.355 AMI=0.587 FMI=0.471
# 	 Linkage: average
# ARI=0.317 AMI=0.559 FMI=0.467
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.085 AMI=0.047 FMI=0.686
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.034 AMI=0.014 FMI=0.606
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.034 AMI=0.014 FMI=0.606
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.030 AMI=0.030 FMI=0.530
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.034 AMI=0.014 FMI=0.606
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.034 AMI=0.014 FMI=0.606
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.446/0.533/0.527/0.620
# AMI=0.625/0.677/0.680/0.726
# FMI=0.521/0.594/0.589/0.664
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.323/0.415/0.574
# AMI=0.000/0.436/0.600/0.724
# FMI=0.000/0.374/0.494/0.631
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.188/0.208/0.203/0.220
# AMI=0.117/0.132/0.127/0.141
# FMI=0.620/0.630/0.629/0.635
# 	 GMM min/mean/median/max
# ARI=0.135/0.188/0.196/0.220
# AMI=0.092/0.121/0.123/0.141
# FMI=0.584/0.618/0.623/0.635
# 	 COBE: crank=2
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.591 AMI=0.788 FMI=0.676
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.731 FMI=0.622
# 	 Linkage: average
# ARI=0.542 AMI=0.732 FMI=0.620
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.591 AMI=0.788 FMI=0.676
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.048 AMI=0.085 FMI=0.553
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.192 AMI=0.165 FMI=0.608
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.192 AMI=0.165 FMI=0.608
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.029 AMI=0.018 FMI=0.531
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.192 AMI=0.165 FMI=0.608
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.192 AMI=0.165 FMI=0.608
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.543/0.528/0.656
# AMI=0.659/0.710/0.708/0.768
# FMI=0.557/0.612/0.602/0.702
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.343/0.486/0.640
# AMI=0.000/0.449/0.661/0.742
# FMI=0.000/0.386/0.555/0.681
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.079/0.127/0.136/0.175
# AMI=0.053/0.087/0.097/0.112
# FMI=0.554/0.581/0.583/0.609
# 	 GMM min/mean/median/max
# ARI=-0.007/0.089/0.070/0.204
# AMI=-0.006/0.074/0.091/0.131
# FMI=0.517/0.565/0.565/0.626
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.591 AMI=0.788 FMI=0.676
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.512 AMI=0.695 FMI=0.581
# 	 Linkage: average
# ARI=0.540 AMI=0.706 FMI=0.606
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.591 AMI=0.788 FMI=0.676
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.046 AMI=0.010 FMI=0.619
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.036 AMI=0.038 FMI=0.534
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.036 AMI=0.038 FMI=0.534
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.053 AMI=0.016 FMI=0.598
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.036 AMI=0.038 FMI=0.534
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.036 AMI=0.038 FMI=0.534
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.546/0.538/0.681
# AMI=0.658/0.712/0.706/0.784
# FMI=0.557/0.614/0.611/0.721
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.345/0.493/0.632
# AMI=0.000/0.456/0.665/0.777
# FMI=0.000/0.390/0.561/0.674
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.070/0.106/0.089/0.175
# AMI=0.050/0.073/0.061/0.117
# FMI=0.549/0.569/0.560/0.607
# 	 GMM min/mean/median/max
# ARI=-0.008/0.064/0.060/0.199
# AMI=-0.006/0.041/0.039/0.119
# FMI=0.514/0.551/0.548/0.641
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.731 FMI=0.622
# 	 Linkage: average
# ARI=0.540 AMI=0.706 FMI=0.606
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.077 AMI=0.044 FMI=0.560
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.001 AMI=-0.005 FMI=0.532
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.001 AMI=-0.005 FMI=0.532
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.079 AMI=0.055 FMI=0.555
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.001 AMI=-0.005 FMI=0.532
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.001 AMI=-0.005 FMI=0.532
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.541/0.528/0.636
# AMI=0.659/0.709/0.708/0.751
# FMI=0.557/0.611/0.602/0.684
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.344/0.493/0.640
# AMI=0.000/0.451/0.665/0.742
# FMI=0.000/0.387/0.561/0.681
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.061/0.116/0.120/0.173
# AMI=0.048/0.069/0.069/0.105
# FMI=0.544/0.582/0.585/0.615
# 	 GMM min/mean/median/max
# ARI=-0.003/0.085/0.074/0.190
# AMI=-0.005/0.068/0.063/0.126
# FMI=0.517/0.563/0.551/0.615
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.497 AMI=0.696 FMI=0.592
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.374 AMI=0.649 FMI=0.529
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.583 AMI=0.736 FMI=0.641
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.477 AMI=0.664 FMI=0.552
# 	 Linkage: average
# ARI=0.531 AMI=0.707 FMI=0.604
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.583 AMI=0.736 FMI=0.641
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.128 AMI=0.068 FMI=0.606
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.024 AMI=0.002 FMI=0.571
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.024 AMI=0.002 FMI=0.571
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.050 AMI=0.027 FMI=0.545
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.024 AMI=0.002 FMI=0.571
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.024 AMI=0.002 FMI=0.571
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.528/0.521/0.612
# AMI=0.671/0.706/0.709/0.740
# FMI=0.557/0.602/0.600/0.663
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.376/0.510/0.612
# AMI=0.000/0.495/0.693/0.806
# FMI=0.000/0.424/0.584/0.673
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.135/0.172/0.174/0.203
# AMI=0.092/0.111/0.110/0.127
# FMI=0.584/0.608/0.612/0.629
# 	 GMM min/mean/median/max
# ARI=-0.006/0.108/0.124/0.206
# AMI=-0.006/0.077/0.095/0.140
# FMI=0.516/0.575/0.580/0.626
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.477 AMI=0.664 FMI=0.552
# 	 Linkage: average
# ARI=0.530 AMI=0.704 FMI=0.601
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.000 AMI=-0.006 FMI=0.545
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.061 AMI=0.019 FMI=0.643
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.061 AMI=0.019 FMI=0.643
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.015 AMI=-0.006 FMI=0.619
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.061 AMI=0.019 FMI=0.643
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.061 AMI=0.019 FMI=0.643
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.472/0.561/0.555/0.681
# AMI=0.671/0.725/0.731/0.784
# FMI=0.573/0.627/0.627/0.721
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.347/0.502/0.612
# AMI=0.000/0.461/0.673/0.806
# FMI=0.000/0.393/0.575/0.673
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.121/0.171/0.173/0.204
# AMI=0.072/0.106/0.106/0.131
# FMI=0.584/0.612/0.615/0.633
# 	 GMM min/mean/median/max
# ARI=-0.003/0.124/0.160/0.206
# AMI=-0.004/0.086/0.110/0.140
# FMI=0.516/0.583/0.598/0.627
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.591 AMI=0.788 FMI=0.676
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.731 FMI=0.622
# 	 Linkage: average
# ARI=0.540 AMI=0.706 FMI=0.606
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.591 AMI=0.788 FMI=0.676
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.041 AMI=0.050 FMI=0.609
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.006 FMI=0.520
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.006 FMI=0.520
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.088 AMI=0.053 FMI=0.564
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.006 FMI=0.520
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.006 FMI=0.520
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.543/0.528/0.681
# AMI=0.659/0.711/0.708/0.784
# FMI=0.557/0.613/0.602/0.721
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.344/0.493/0.640
# AMI=0.000/0.451/0.665/0.742
# FMI=0.000/0.387/0.561/0.681
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.135/0.164/0.147/0.220
# AMI=0.088/0.105/0.095/0.141
# FMI=0.586/0.604/0.593/0.638
# 	 GMM min/mean/median/max
# ARI=0.002/0.124/0.161/0.204
# AMI=-0.003/0.090/0.109/0.155
# FMI=0.523/0.583/0.599/0.629
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.731 FMI=0.622
# 	 Linkage: average
# ARI=0.530 AMI=0.704 FMI=0.601
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.124 AMI=0.115 FMI=0.576
# 	 Linkage: average
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.110 AMI=0.136 FMI=0.575
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.110 AMI=0.136 FMI=0.575
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.141 AMI=0.076 FMI=0.614
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.110 AMI=0.136 FMI=0.575
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.110 AMI=0.136 FMI=0.575
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.547/0.550/0.681
# AMI=0.657/0.715/0.715/0.784
# FMI=0.556/0.615/0.620/0.721
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.344/0.493/0.612
# AMI=0.000/0.455/0.665/0.777
# FMI=0.000/0.389/0.561/0.658
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.146/0.188/0.188/0.203
# AMI=0.087/0.116/0.117/0.127
# FMI=0.599/0.624/0.624/0.636
# 	 GMM min/mean/median/max
# ARI=0.035/0.133/0.133/0.201
# AMI=0.080/0.095/0.096/0.121
# FMI=0.561/0.591/0.591/0.636
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.522 AMI=0.757 FMI=0.623
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.374 AMI=0.649 FMI=0.529
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.620 AMI=0.753 FMI=0.674
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.480 AMI=0.667 FMI=0.557
# 	 Linkage: average
# ARI=0.531 AMI=0.707 FMI=0.604
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.620 AMI=0.753 FMI=0.674
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.023 AMI=-0.002 FMI=0.680
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.023 AMI=-0.002 FMI=0.680
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.013 AMI=-0.006 FMI=0.582
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.023 AMI=-0.002 FMI=0.680
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.023 AMI=-0.002 FMI=0.680
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.537/0.540/0.620
# AMI=0.662/0.711/0.711/0.753
# FMI=0.557/0.609/0.610/0.669
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.353/0.510/0.612
# AMI=0.000/0.461/0.693/0.806
# FMI=0.000/0.397/0.584/0.673
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.147/0.163/0.162/0.190
# AMI=0.091/0.107/0.108/0.126
# FMI=0.593/0.601/0.599/0.615
# 	 GMM min/mean/median/max
# ARI=-0.010/0.081/0.065/0.176
# AMI=-0.006/0.058/0.073/0.122
# FMI=0.515/0.561/0.556/0.612
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.731 FMI=0.622
# 	 Linkage: average
# ARI=0.540 AMI=0.706 FMI=0.606
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.004 AMI=-0.009 FMI=0.649
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.076 AMI=0.030 FMI=0.601
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.076 AMI=0.030 FMI=0.601
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.160 AMI=0.090 FMI=0.654
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.076 AMI=0.030 FMI=0.601
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.076 AMI=0.030 FMI=0.601
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.534/0.523/0.681
# AMI=0.658/0.704/0.703/0.784
# FMI=0.557/0.604/0.595/0.721
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.191/0.000/0.640
# AMI=0.000/0.246/0.000/0.742
# FMI=0.000/0.213/0.000/0.681
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.135/0.165/0.161/0.190
# AMI=0.088/0.106/0.104/0.126
# FMI=0.586/0.605/0.604/0.623
# 	 GMM min/mean/median/max
# ARI=-0.004/0.119/0.153/0.206
# AMI=-0.004/0.085/0.096/0.155
# FMI=0.513/0.580/0.601/0.619
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.420 AMI=0.623 FMI=0.516
# 	 Linkage: average
# ARI=0.511 AMI=0.739 FMI=0.611
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.389 AMI=0.607 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.606 FMI=0.504
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.731 FMI=0.622
# 	 Linkage: average
# ARI=0.530 AMI=0.704 FMI=0.601
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.653 AMI=0.782 FMI=0.699
# 	 Linkage: average
# ARI=0.565 AMI=0.777 FMI=0.658
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.017 AMI=-0.004 FMI=0.560
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.060 AMI=0.044 FMI=0.545
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.060 AMI=0.044 FMI=0.545
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.106 AMI=0.056 FMI=0.586
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.060 AMI=0.044 FMI=0.545
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.060 AMI=0.044 FMI=0.545
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.448/0.546/0.536/0.681
# AMI=0.657/0.717/0.717/0.784
# FMI=0.556/0.616/0.614/0.721
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.344/0.493/0.612
# AMI=0.000/0.455/0.665/0.777
# FMI=0.000/0.389/0.561/0.658
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.100/0.170/0.181/0.203
# AMI=0.067/0.106/0.113/0.127
# FMI=0.566/0.609/0.616/0.629
# 	 GMM min/mean/median/max
# ARI=-0.005/0.132/0.142/0.204
# AMI=-0.002/0.085/0.094/0.131
# FMI=0.513/0.586/0.590/0.629
# 	 COBE: crank=3
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.450 AMI=0.680 FMI=0.551
# 	 Linkage: average
# ARI=0.526 AMI=0.742 FMI=0.628
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.495 AMI=0.680 FMI=0.576
# 	 Linkage: average
# ARI=0.223 AMI=0.472 FMI=0.430
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.490 AMI=0.658 FMI=0.560
# 	 Linkage: average
# ARI=0.563 AMI=0.774 FMI=0.652
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.044 AMI=0.031 FMI=0.537
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.051 AMI=0.030 FMI=0.543
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.051 AMI=0.030 FMI=0.543
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.001 AMI=-0.001 FMI=0.516
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.051 AMI=0.030 FMI=0.543
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.051 AMI=0.030 FMI=0.543
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.544/0.546/0.668
# AMI=0.636/0.717/0.707/0.772
# FMI=0.545/0.616/0.607/0.712
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.284/0.426/0.634
# AMI=0.000/0.374/0.608/0.748
# FMI=0.000/0.324/0.514/0.683
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.002/0.007/0.008/0.013
# AMI=-0.004/0.004/0.006/0.009
# FMI=0.515/0.518/0.519/0.521
# 	 GMM min/mean/median/max
# ARI=-0.002/0.027/0.029/0.058
# AMI=-0.004/0.015/0.015/0.031
# FMI=0.515/0.532/0.532/0.557
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.450 AMI=0.680 FMI=0.551
# 	 Linkage: average
# ARI=0.526 AMI=0.742 FMI=0.628
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.474 AMI=0.651 FMI=0.558
# 	 Linkage: average
# ARI=0.223 AMI=0.472 FMI=0.430
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.623 AMI=0.734 FMI=0.669
# 	 Linkage: average
# ARI=0.563 AMI=0.774 FMI=0.652
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.012 AMI=0.093 FMI=0.563
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.121 AMI=0.072 FMI=0.584
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.121 AMI=0.072 FMI=0.584
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.006 AMI=-0.007 FMI=0.594
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.121 AMI=0.072 FMI=0.584
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.121 AMI=0.072 FMI=0.584
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.542/0.533/0.675
# AMI=0.639/0.714/0.714/0.776
# FMI=0.550/0.613/0.614/0.718
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.314/0.485/0.634
# AMI=0.000/0.413/0.651/0.748
# FMI=0.000/0.357/0.563/0.683
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.121/0.156/0.149/0.189
# AMI=0.072/0.102/0.104/0.121
# FMI=0.584/0.599/0.592/0.620
# 	 GMM min/mean/median/max
# ARI=-0.003/0.140/0.162/0.205
# AMI=-0.005/0.098/0.108/0.135
# FMI=0.517/0.588/0.599/0.623
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.450 AMI=0.680 FMI=0.551
# 	 Linkage: average
# ARI=0.526 AMI=0.742 FMI=0.628
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.474 AMI=0.651 FMI=0.558
# 	 Linkage: average
# ARI=0.223 AMI=0.472 FMI=0.430
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.623 AMI=0.734 FMI=0.669
# 	 Linkage: average
# ARI=0.563 AMI=0.774 FMI=0.652
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.021 AMI=0.000 FMI=0.688
# 	 Linkage: average
# ARI=-0.005 AMI=-0.011 FMI=0.693
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.007 FMI=0.567
# 	 Linkage: average
# ARI=-0.026 AMI=0.006 FMI=0.680
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.007 FMI=0.567
# 	 Linkage: average
# ARI=-0.026 AMI=0.006 FMI=0.680
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.005 AMI=-0.014 FMI=0.720
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.007 FMI=0.567
# 	 Linkage: average
# ARI=-0.026 AMI=0.006 FMI=0.680
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.007 FMI=0.567
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.482/0.553/0.549/0.675
# AMI=0.639/0.716/0.716/0.776
# FMI=0.550/0.620/0.617/0.718
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.313/0.480/0.634
# AMI=0.000/0.412/0.650/0.748
# FMI=0.000/0.356/0.558/0.683
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.051/0.108/0.109/0.159
# AMI=0.030/0.064/0.062/0.096
# FMI=0.543/0.578/0.579/0.618
# 	 GMM min/mean/median/max
# ARI=-0.007/0.087/0.079/0.198
# AMI=-0.003/0.073/0.076/0.141
# FMI=0.513/0.569/0.562/0.645
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.450 AMI=0.680 FMI=0.551
# 	 Linkage: average
# ARI=0.383 AMI=0.666 FMI=0.534
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.495 AMI=0.680 FMI=0.576
# 	 Linkage: average
# ARI=0.223 AMI=0.472 FMI=0.430
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.490 AMI=0.658 FMI=0.560
# 	 Linkage: average
# ARI=0.563 AMI=0.774 FMI=0.652
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.083 AMI=0.038 FMI=0.580
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.113 AMI=0.055 FMI=0.608
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.113 AMI=0.055 FMI=0.608
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.029 AMI=0.007 FMI=0.556
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.113 AMI=0.055 FMI=0.608
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.113 AMI=0.055 FMI=0.608
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.546/0.546/0.668
# AMI=0.636/0.715/0.704/0.772
# FMI=0.539/0.616/0.606/0.712
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.283/0.409/0.634
# AMI=0.000/0.374/0.603/0.748
# FMI=0.000/0.323/0.502/0.683
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.019/0.018/-0.002/0.081
# AMI=-0.007/0.012/0.008/0.036
# FMI=0.524/0.546/0.541/0.585
# 	 GMM min/mean/median/max
# ARI=-0.022/0.016/0.009/0.088
# AMI=-0.006/0.015/0.012/0.057
# FMI=0.517/0.540/0.533/0.603
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.450 AMI=0.680 FMI=0.551
# 	 Linkage: average
# ARI=0.526 AMI=0.742 FMI=0.628
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.495 AMI=0.680 FMI=0.576
# 	 Linkage: average
# ARI=0.223 AMI=0.472 FMI=0.430
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.490 AMI=0.658 FMI=0.560
# 	 Linkage: average
# ARI=0.563 AMI=0.774 FMI=0.652
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.540 AMI=0.698 FMI=0.604
# 	 Linkage: average
# ARI=0.449 AMI=0.671 FMI=0.561
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# ...
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.006 FMI=0.520
# 	 Linkage: average
# ARI=-0.042 AMI=0.038 FMI=0.646
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.057 AMI=0.017 FMI=0.620
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.057 AMI=0.017 FMI=0.620
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.033 AMI=0.032 FMI=0.587
# 	 Linkage: average
# ARI=-0.021 AMI=0.000 FMI=0.688
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.057 AMI=0.017 FMI=0.620
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.057 AMI=0.017 FMI=0.620
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.512/0.574/0.576/0.675
# AMI=0.683/0.736/0.737/0.776
# FMI=0.585/0.640/0.638/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.235/0.000/0.575
# AMI=0.000/0.315/0.000/0.733
# FMI=0.000/0.269/0.000/0.632
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.006/0.071/0.073/0.109
# AMI=-0.006/0.042/0.041/0.067
# FMI=0.517/0.556/0.556/0.579
# 	 GMM min/mean/median/max
# ARI=-0.007/0.065/0.069/0.145
# AMI=-0.005/0.046/0.050/0.171
# FMI=0.513/0.551/0.549/0.602
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.292 AMI=0.563 FMI=0.445
# 	 Linkage: average
# ARI=0.385 AMI=0.647 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.285 AMI=0.530 FMI=0.430
# 	 Linkage: average
# ARI=0.140 AMI=0.362 FMI=0.358
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.533 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.615 AMI=0.741 FMI=0.665
# 	 Linkage: average
# ARI=0.570 AMI=0.736 FMI=0.639
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.533 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.060 AMI=0.041 FMI=0.545
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.018 AMI=0.016 FMI=0.524
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.018 AMI=0.016 FMI=0.524
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.044 AMI=0.039 FMI=0.536
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.018 AMI=0.016 FMI=0.524
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.018 AMI=0.016 FMI=0.524
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.562/0.546/0.675
# AMI=0.676/0.732/0.741/0.776
# FMI=0.561/0.631/0.631/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.325/0.498/0.611
# AMI=0.000/0.423/0.669/0.743
# FMI=0.000/0.366/0.571/0.660
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.003/0.008/0.007/0.016
# AMI=0.012/0.018/0.018/0.029
# FMI=0.521/0.524/0.524/0.529
# 	 GMM min/mean/median/max
# ARI=0.018/0.030/0.018/0.069
# AMI=0.019/0.024/0.019/0.046
# FMI=0.524/0.531/0.524/0.554
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.292 AMI=0.563 FMI=0.445
# 	 Linkage: average
# ARI=0.385 AMI=0.647 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.316 AMI=0.550 FMI=0.451
# 	 Linkage: average
# ARI=0.232 AMI=0.484 FMI=0.429
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.533 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.590 AMI=0.730 FMI=0.647
# 	 Linkage: average
# ARI=0.570 AMI=0.736 FMI=0.639
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.533 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.109 AMI=0.066 FMI=0.577
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.004 AMI=-0.004 FMI=0.532
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.004 AMI=-0.004 FMI=0.532
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.133 AMI=0.080 FMI=0.591
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.004 AMI=-0.004 FMI=0.532
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.004 AMI=-0.004 FMI=0.532
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.560/0.540/0.675
# AMI=0.676/0.732/0.739/0.788
# FMI=0.561/0.630/0.621/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.300/0.459/0.664
# AMI=0.000/0.389/0.667/0.775
# FMI=0.000/0.337/0.555/0.703
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.145/0.163/0.159/0.173
# AMI=0.084/0.097/0.096/0.105
# FMI=0.599/0.610/0.610/0.615
# 	 GMM min/mean/median/max
# ARI=-0.000/0.083/0.088/0.173
# AMI=-0.003/0.048/0.051/0.105
# FMI=0.517/0.565/0.566/0.615
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.312 AMI=0.530 FMI=0.435
# 	 Linkage: average
# ARI=0.323 AMI=0.594 FMI=0.479
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.250 AMI=0.493 FMI=0.402
# 	 Linkage: average
# ARI=0.233 AMI=0.475 FMI=0.419
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.583 AMI=0.736 FMI=0.641
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.624 AMI=0.742 FMI=0.672
# 	 Linkage: average
# ARI=0.466 AMI=0.688 FMI=0.570
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.583 AMI=0.736 FMI=0.641
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.060 AMI=0.058 FMI=0.545
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.097 AMI=0.053 FMI=0.576
# 	 Linkage: average
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.097 AMI=0.053 FMI=0.576
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.030 AMI=0.082 FMI=0.553
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.097 AMI=0.053 FMI=0.576
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.097 AMI=0.053 FMI=0.576
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.456/0.561/0.562/0.627
# AMI=0.700/0.738/0.743/0.779
# FMI=0.567/0.634/0.630/0.675
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.301/0.455/0.680
# AMI=0.000/0.390/0.641/0.757
# FMI=0.000/0.339/0.541/0.719
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.039/0.051/0.048/0.123
# AMI=0.071/0.086/0.085/0.124
# FMI=0.547/0.553/0.553/0.577
# 	 GMM min/mean/median/max
# ARI=-0.008/0.077/0.062/0.163
# AMI=-0.006/0.096/0.096/0.148
# FMI=0.513/0.562/0.557/0.594
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.292 AMI=0.563 FMI=0.445
# 	 Linkage: average
# ARI=0.385 AMI=0.647 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.285 AMI=0.530 FMI=0.430
# 	 Linkage: average
# ARI=0.140 AMI=0.362 FMI=0.358
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.526 AMI=0.702 FMI=0.593
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.615 AMI=0.741 FMI=0.665
# 	 Linkage: average
# ARI=0.570 AMI=0.736 FMI=0.639
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.526 AMI=0.702 FMI=0.593
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.081 AMI=0.036 FMI=0.585
# 	 Linkage: average
# ARI=0.019 AMI=-0.004 FMI=0.662
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.252 AMI=0.164 FMI=0.654
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.252 AMI=0.164 FMI=0.654
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.008 AMI=-0.003 FMI=0.515
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.252 AMI=0.164 FMI=0.654
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.252 AMI=0.164 FMI=0.654
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.562/0.546/0.675
# AMI=0.676/0.731/0.740/0.776
# FMI=0.561/0.631/0.628/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.166/0.000/0.611
# AMI=0.000/0.215/0.000/0.736
# FMI=0.000/0.186/0.000/0.660
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.052/0.090/0.079/0.133
# AMI=0.036/0.058/0.055/0.080
# FMI=0.541/0.563/0.556/0.591
# 	 GMM min/mean/median/max
# ARI=0.000/0.051/0.030/0.122
# AMI=-0.002/0.032/0.024/0.076
# FMI=0.516/0.543/0.529/0.583
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.292 AMI=0.563 FMI=0.445
# 	 Linkage: average
# ARI=0.385 AMI=0.647 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.285 AMI=0.530 FMI=0.430
# 	 Linkage: average
# ARI=0.140 AMI=0.362 FMI=0.358
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.526 AMI=0.702 FMI=0.593
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.710 FMI=0.620
# 	 Linkage: average
# ARI=0.570 AMI=0.736 FMI=0.639
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.526 AMI=0.702 FMI=0.593
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.045 AMI=0.064 FMI=0.623
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.010 AMI=-0.003 FMI=0.549
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.010 AMI=-0.003 FMI=0.549
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.040 AMI=0.032 FMI=0.652
# 	 Linkage: average
# ARI=-0.005 AMI=-0.011 FMI=0.693
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.010 AMI=-0.003 FMI=0.549
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.010 AMI=-0.003 FMI=0.549
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.563/0.546/0.675
# AMI=0.676/0.731/0.740/0.776
# FMI=0.561/0.631/0.628/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.325/0.498/0.611
# AMI=0.000/0.423/0.669/0.743
# FMI=0.000/0.366/0.571/0.660
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.008/0.008/-0.004/0.123
# AMI=-0.006/0.007/-0.005/0.090
# FMI=0.512/0.522/0.517/0.576
# 	 GMM min/mean/median/max
# ARI=-0.008/0.071/0.072/0.163
# AMI=-0.006/0.076/0.100/0.147
# FMI=0.512/0.556/0.565/0.596
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.292 AMI=0.563 FMI=0.445
# 	 Linkage: average
# ARI=0.385 AMI=0.647 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.285 AMI=0.530 FMI=0.430
# 	 Linkage: average
# ARI=0.140 AMI=0.362 FMI=0.358
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.526 AMI=0.702 FMI=0.593
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.557 AMI=0.710 FMI=0.620
# 	 Linkage: average
# ARI=0.570 AMI=0.736 FMI=0.639
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.526 AMI=0.702 FMI=0.593
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=-0.005 AMI=-0.011 FMI=0.693
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.026 AMI=0.000 FMI=0.670
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.026 AMI=0.000 FMI=0.670
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.044 AMI=0.045 FMI=0.640
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.026 AMI=0.000 FMI=0.670
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.026 AMI=0.000 FMI=0.670
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.458/0.563/0.546/0.675
# AMI=0.676/0.731/0.740/0.776
# FMI=0.561/0.631/0.631/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.298/0.460/0.611
# AMI=0.000/0.390/0.646/0.743
# FMI=0.000/0.337/0.546/0.660
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.011/0.024/0.022/0.041
# AMI=0.002/0.009/0.008/0.018
# FMI=0.526/0.534/0.534/0.546
# 	 GMM min/mean/median/max
# ARI=-0.030/0.038/0.042/0.075
# AMI=0.005/0.023/0.023/0.080
# FMI=0.534/0.546/0.541/0.589
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.292 AMI=0.563 FMI=0.445
# 	 Linkage: average
# ARI=0.385 AMI=0.647 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.381 AMI=0.602 FMI=0.489
# 	 Linkage: average
# ARI=0.232 AMI=0.484 FMI=0.429
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.533 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.615 AMI=0.741 FMI=0.665
# 	 Linkage: average
# ARI=0.570 AMI=0.736 FMI=0.639
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.533 AMI=0.706 FMI=0.599
# 	 Linkage: average
# ARI=0.531 AMI=0.754 FMI=0.623
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.016 AMI=0.032 FMI=0.327
# 	 Linkage: average
# ARI=0.016 AMI=0.032 FMI=0.327
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.075 AMI=0.038 FMI=0.566
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=-0.021 AMI=0.000 FMI=0.688
# 	 Linkage: average
# ARI=-0.026 AMI=0.006 FMI=0.680
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.021 AMI=0.000 FMI=0.688
# 	 Linkage: average
# ARI=-0.026 AMI=0.006 FMI=0.680
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.049 AMI=0.012 FMI=0.643
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.021 AMI=0.000 FMI=0.688
# 	 Linkage: average
# ARI=-0.026 AMI=0.006 FMI=0.680
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=-0.021 AMI=0.000 FMI=0.688
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.513/0.568/0.548/0.675
# AMI=0.676/0.733/0.739/0.776
# FMI=0.583/0.634/0.626/0.716
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# GMM: diverged
# 	 GMM min/mean/median/max
# ARI=0.000/0.328/0.498/0.664
# AMI=0.000/0.425/0.669/0.775
# FMI=0.000/0.369/0.571/0.703
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.009/0.000/0.001/0.017
# AMI=0.009/0.017/0.018/0.029
# FMI=0.525/0.527/0.527/0.529
# 	 GMM min/mean/median/max
# ARI=0.006/0.027/0.011/0.079
# AMI=0.018/0.027/0.022/0.051
# FMI=0.524/0.532/0.526/0.556

# %%
result_ac, result_kg = np.array(result_ac), np.array(result_kg)
np.savez_compressed(
    'cobe_contrasted_clustering',
    result_ac=result_ac,
    result_kg=result_kg,
    random_states=random_states,
    clust_alg_names=clust_alg_names,
    Ntrials=Ntrials,
    Ntrials_cobe=Ntrials_cobe,
    np_random_seed=np_random_seed,
    affinity_names=affinity_names,
    linkage=linkage,
    dataset_names=dataset_names
)

# %%
stat_min = np.min(result, axis=2)
stat_max = np.max(result, axis=2)
stat_mean = np.mean(result, axis=2)
stat_median = np.median(result, axis=2)
for i in range(1, len(dataset_names)):
    print(dataset_names[i])
    for k_affinity in range(len(affinity_names)):
        current_affinity = affinity_names[k_affinity]
        print(f'\t\t Affinity: {current_affinity}')
        for k_linkage in range(len(linkage)):
            current_linkage = linkage[k_linkage]
            print(f'\t Linkage: {current_linkage}')
            for k_comr in range(len(commonRanks)):
                commonRank = commonRanks[k_comr]
                print(f'rank={commonRank}')
                print(
                    f'ARI={stat_min[i, k_comr, k_affinity, k_linkage, 0]:.3f}/'
                    f'{stat_mean[i, k_comr, k_affinity, k_linkage, 0]:.3f}/'
                    f'{stat_median[i, k_comr, k_affinity, k_linkage, 0]:.3f}/'
                    f'{stat_max[i, k_comr, k_affinity, k_linkage, 0]:.3f}/'
                )
                print(
                    f'AMI={stat_min[i, k_comr, k_affinity, k_linkage, 1]:.3f}/'
                    f'{stat_mean[i, k_comr, k_affinity, k_linkage, 1]:.3f}/'
                    f'{stat_median[i, k_comr, k_affinity, k_linkage, 1]:.3f}/'
                    f'{stat_max[i, k_comr, k_affinity, k_linkage, 1]:.3f}/'
                )
                print(
                    f'FMI={stat_min[i, k_comr, k_affinity, k_linkage, 2]:.3f}/'
                    f'{stat_mean[i, k_comr, k_affinity, k_linkage, 2]:.3f}/'
                    f'{stat_median[i, k_comr, k_affinity, k_linkage, 2]:.3f}/'
                    f'{stat_max[i, k_comr, k_affinity, k_linkage, 2]:.3f}/'
                )
            print('\n')
# Out:
# smni
# 		 Affinity: l1
# 	 Linkage: complete
# rank=1
# ARI=-0.048/0.033/0.023/0.198/
# AMI=-0.006/0.042/0.045/0.117/
# FMI=0.535/0.590/0.591/0.645/
# rank=2
# ARI=-0.013/0.064/0.067/0.189/
# AMI=-0.014/0.045/0.038/0.133/
# FMI=0.521/0.583/0.573/0.712/
# rank=3
# ARI=-0.026/0.065/0.073/0.188/
# AMI=-0.007/0.054/0.051/0.139/
# FMI=0.527/0.590/0.585/0.674/
# rank=4
# ARI=-0.034/0.049/0.015/0.207/
# AMI=-0.007/0.049/0.033/0.180/
# FMI=0.512/0.573/0.572/0.729/
# rank=5
# ARI=-0.035/0.029/0.011/0.125/
# AMI=-0.014/0.028/0.019/0.096/
# FMI=0.522/0.591/0.560/0.712/
# rank=6
# ARI=-0.029/0.034/0.017/0.159/
# AMI=-0.011/0.042/0.041/0.147/
# FMI=0.523/0.601/0.574/0.729/
# rank=7
# ARI=-0.037/-0.003/-0.008/0.066/
# AMI=-0.014/0.006/0.002/0.053/
# FMI=0.515/0.607/0.602/0.720/
# rank=8
# ARI=-0.040/0.018/-0.001/0.128/
# AMI=-0.014/0.027/0.027/0.075/
# FMI=0.518/0.595/0.570/0.729/
# rank=9
# ARI=-0.044/0.015/0.009/0.118/
# AMI=-0.011/0.025/0.010/0.119/
# FMI=0.514/0.593/0.574/0.704/
# rank=10
# ARI=-0.041/0.002/-0.002/0.087/
# AMI=-0.014/0.018/0.011/0.080/
# FMI=0.519/0.593/0.577/0.720/
#
#
# 	 Linkage: average
# rank=1
# ARI=-0.002/0.011/0.013/0.013/
# AMI=-0.014/0.004/0.009/0.009/
# FMI=0.712/0.727/0.729/0.729/
# rank=2
# ARI=-0.038/0.006/0.013/0.013/
# AMI=-0.014/0.007/0.009/0.052/
# FMI=0.676/0.722/0.729/0.729/
# rank=3
# ARI=-0.002/0.011/0.013/0.013/
# AMI=-0.014/0.004/0.009/0.009/
# FMI=0.712/0.727/0.729/0.729/
# rank=4
# ARI=-0.016/0.009/0.013/0.013/
# AMI=-0.014/0.003/0.009/0.009/
# FMI=0.678/0.724/0.729/0.729/
# rank=5
# ARI=-0.009/0.009/0.013/0.013/
# AMI=-0.014/0.002/0.009/0.009/
# FMI=0.704/0.724/0.729/0.729/
# rank=6
# ARI=-0.009/0.009/0.013/0.013/
# AMI=-0.014/0.004/0.009/0.009/
# FMI=0.704/0.726/0.729/0.729/
# rank=7
# ARI=-0.037/0.007/0.013/0.040/
# AMI=-0.014/0.003/0.009/0.055/
# FMI=0.659/0.721/0.728/0.729/
# rank=8
# ARI=-0.034/0.009/0.013/0.013/
# AMI=-0.014/0.006/0.009/0.019/
# FMI=0.666/0.725/0.729/0.729/
# rank=9
# ARI=-0.007/0.010/0.013/0.013/
# AMI=-0.014/0.005/0.009/0.009/
# FMI=0.712/0.727/0.729/0.729/
# rank=10
# ARI=-0.007/0.012/0.013/0.040/
# AMI=-0.014/0.007/0.009/0.055/
# FMI=0.720/0.727/0.729/0.729/
#
#
# 		 Affinity: l2
# 	 Linkage: complete
# rank=1
# ARI=-0.010/0.077/0.088/0.159/
# AMI=-0.006/0.048/0.057/0.108/
# FMI=0.513/0.587/0.578/0.669/
# rank=2
# ARI=-0.009/0.080/0.080/0.204/
# AMI=-0.006/0.044/0.048/0.131/
# FMI=0.516/0.594/0.597/0.697/
# rank=3
# ARI=-0.025/0.070/0.051/0.169/
# AMI=-0.000/0.053/0.063/0.148/
# FMI=0.519/0.585/0.583/0.698/
# rank=4
# ARI=-0.021/0.041/0.028/0.164/
# AMI=-0.010/0.032/0.022/0.112/
# FMI=0.512/0.587/0.565/0.686/
# rank=5
# ARI=-0.043/0.027/0.015/0.111/
# AMI=-0.007/0.032/0.024/0.133/
# FMI=0.513/0.584/0.580/0.690/
# rank=6
# ARI=-0.041/0.038/0.008/0.201/
# AMI=-0.007/0.034/0.035/0.121/
# FMI=0.518/0.582/0.575/0.649/
# rank=7
# ARI=-0.034/0.018/0.012/0.091/
# AMI=-0.007/0.006/-0.000/0.042/
# FMI=0.512/0.586/0.589/0.729/
# rank=8
# ARI=-0.021/0.037/0.025/0.202/
# AMI=-0.006/0.024/0.008/0.154/
# FMI=0.512/0.585/0.580/0.688/
# rank=9
# ARI=-0.033/0.016/0.004/0.111/
# AMI=-0.014/0.014/0.002/0.108/
# FMI=0.513/0.583/0.578/0.712/
# rank=10
# ARI=-0.013/0.004/-0.005/0.045/
# AMI=-0.009/-0.000/-0.005/0.015/
# FMI=0.511/0.569/0.541/0.717/
#
#
# 	 Linkage: average
# rank=1
# ARI=-0.035/-0.001/0.001/0.013/
# AMI=-0.014/0.006/0.009/0.044/
# FMI=0.683/0.718/0.723/0.729/
# rank=2
# ARI=-0.037/0.001/0.013/0.013/
# AMI=-0.014/0.005/0.009/0.025/
# FMI=0.659/0.718/0.729/0.729/
# rank=3
# ARI=-0.035/-0.001/0.007/0.013/
# AMI=-0.014/0.006/0.009/0.044/
# FMI=0.683/0.718/0.723/0.729/
# rank=4
# ARI=-0.038/0.002/0.009/0.013/
# AMI=-0.014/0.003/0.009/0.052/
# FMI=0.673/0.715/0.725/0.729/
# rank=5
# ARI=-0.030/0.001/0.001/0.013/
# AMI=-0.014/0.002/0.009/0.035/
# FMI=0.666/0.716/0.723/0.729/
# rank=6
# ARI=-0.020/0.012/0.013/0.064/
# AMI=-0.014/0.008/0.009/0.040/
# FMI=0.567/0.716/0.729/0.729/
# rank=7
# ARI=-0.026/0.003/0.011/0.040/
# AMI=-0.014/0.006/0.009/0.055/
# FMI=0.680/0.719/0.724/0.729/
# rank=8
# ARI=-0.015/0.007/0.011/0.013/
# AMI=-0.014/-0.002/0.002/0.009/
# FMI=0.696/0.722/0.725/0.729/
# rank=9
# ARI=-0.017/0.009/0.013/0.026/
# AMI=-0.014/0.000/0.004/0.032/
# FMI=0.660/0.721/0.724/0.729/
# rank=10
# ARI=-0.007/0.009/0.013/0.026/
# AMI=-0.014/0.002/0.009/0.032/
# FMI=0.702/0.723/0.727/0.729/
#
#
# 		 Affinity: cosine
# 	 Linkage: complete
# rank=1
# ARI=-0.010/0.077/0.088/0.159/
# AMI=-0.006/0.048/0.057/0.108/
# FMI=0.513/0.587/0.578/0.669/
# rank=2
# ARI=-0.009/0.080/0.080/0.204/
# AMI=-0.006/0.044/0.048/0.131/
# FMI=0.516/0.594/0.597/0.697/
# rank=3
# ARI=-0.025/0.070/0.051/0.169/
# AMI=-0.000/0.053/0.063/0.148/
# FMI=0.519/0.585/0.583/0.698/
# rank=4
# ARI=-0.021/0.041/0.028/0.164/
# AMI=-0.010/0.032/0.022/0.112/
# FMI=0.512/0.587/0.565/0.686/
# rank=5
# ARI=-0.043/0.027/0.015/0.111/
# AMI=-0.007/0.032/0.024/0.133/
# FMI=0.513/0.584/0.580/0.690/
# rank=6
# ARI=-0.041/0.038/0.008/0.201/
# AMI=-0.007/0.034/0.035/0.121/
# FMI=0.518/0.582/0.575/0.649/
# rank=7
# ARI=-0.034/0.018/0.012/0.091/
# AMI=-0.007/0.006/-0.000/0.042/
# FMI=0.512/0.586/0.589/0.729/
# rank=8
# ARI=-0.021/0.037/0.025/0.202/
# AMI=-0.006/0.024/0.008/0.154/
# FMI=0.512/0.585/0.580/0.688/
# rank=9
# ARI=-0.033/0.016/0.004/0.111/
# AMI=-0.014/0.014/0.002/0.108/
# FMI=0.513/0.583/0.578/0.712/
# rank=10
# ARI=-0.013/0.004/-0.005/0.045/
# AMI=-0.009/-0.000/-0.005/0.015/
# FMI=0.511/0.569/0.541/0.717/
#
#
# 	 Linkage: average
# rank=1
# ARI=-0.035/-0.002/0.001/0.013/
# AMI=-0.014/0.008/0.009/0.044/
# FMI=0.683/0.716/0.722/0.729/
# rank=2
# ARI=-0.034/0.000/0.009/0.013/
# AMI=-0.014/0.004/0.009/0.019/
# FMI=0.666/0.716/0.726/0.729/
# rank=3
# ARI=-0.021/0.002/0.013/0.013/
# AMI=-0.011/0.006/0.009/0.016/
# FMI=0.688/0.721/0.729/0.729/
# rank=4
# ARI=-0.026/0.003/0.013/0.013/
# AMI=-0.014/0.004/0.009/0.009/
# FMI=0.663/0.718/0.729/0.729/
# rank=5
# ARI=-0.026/0.002/0.009/0.019/
# AMI=-0.014/0.004/0.009/0.026/
# FMI=0.662/0.715/0.723/0.729/
# rank=6
# ARI=-0.021/0.008/0.013/0.063/
# AMI=-0.014/0.006/0.009/0.040/
# FMI=0.670/0.721/0.729/0.729/
# rank=7
# ARI=-0.021/0.002/0.007/0.040/
# AMI=-0.014/0.006/0.009/0.055/
# FMI=0.688/0.719/0.722/0.729/
# rank=8
# ARI=-0.015/0.006/0.013/0.018/
# AMI=-0.014/0.001/0.009/0.009/
# FMI=0.696/0.721/0.729/0.729/
# rank=9
# ARI=-0.002/0.010/0.013/0.026/
# AMI=-0.014/-0.001/-0.001/0.032/
# FMI=0.710/0.723/0.720/0.729/
# rank=10
# ARI=-0.007/0.009/0.013/0.026/
# AMI=-0.014/0.002/0.009/0.032/
# FMI=0.702/0.723/0.727/0.729/
#
#
# 		 Affinity: canberra
# 	 Linkage: complete
# rank=1
# ARI=-0.029/0.049/0.017/0.207/
# AMI=-0.007/0.040/0.024/0.158/
# FMI=0.518/0.579/0.574/0.649/
# rank=2
# ARI=-0.022/0.061/0.053/0.169/
# AMI=-0.006/0.044/0.049/0.140/
# FMI=0.516/0.581/0.573/0.661/
# rank=3
# ARI=-0.036/0.069/0.072/0.166/
# AMI=-0.008/0.044/0.049/0.094/
# FMI=0.524/0.578/0.569/0.648/
# rank=4
# ARI=-0.045/0.044/0.036/0.154/
# AMI=-0.007/0.036/0.035/0.112/
# FMI=0.524/0.582/0.576/0.688/
# rank=5
# ARI=-0.030/0.043/0.029/0.190/
# AMI=-0.007/0.030/0.011/0.126/
# FMI=0.513/0.563/0.560/0.656/
# rank=6
# ARI=-0.039/0.015/-0.002/0.152/
# AMI=-0.011/0.032/0.020/0.101/
# FMI=0.521/0.576/0.560/0.704/
# rank=7
# ARI=-0.036/0.004/-0.002/0.085/
# AMI=-0.012/0.011/-0.003/0.144/
# FMI=0.514/0.590/0.561/0.708/
# rank=8
# ARI=-0.045/0.008/-0.009/0.145/
# AMI=-0.008/0.028/0.008/0.147/
# FMI=0.513/0.588/0.591/0.673/
# rank=9
# ARI=-0.034/0.013/-0.008/0.144/
# AMI=-0.008/0.027/0.010/0.154/
# FMI=0.513/0.595/0.577/0.698/
# rank=10
# ARI=-0.032/-0.000/-0.010/0.088/
# AMI=-0.007/0.009/0.006/0.053/
# FMI=0.512/0.576/0.568/0.727/
#
#
# 	 Linkage: average
# rank=1
# ARI=-0.035/-0.000/0.005/0.013/
# AMI=-0.014/-0.001/-0.004/0.044/
# FMI=0.683/0.715/0.720/0.729/
# rank=2
# ARI=-0.021/0.006/0.009/0.013/
# AMI=-0.014/-0.001/0.005/0.009/
# FMI=0.688/0.722/0.726/0.729/
# rank=3
# ARI=-0.044/-0.001/0.005/0.013/
# AMI=-0.014/0.003/0.007/0.045/
# FMI=0.640/0.715/0.720/0.729/
# rank=4
# ARI=-0.026/0.000/0.005/0.013/
# AMI=-0.014/0.003/0.009/0.026/
# FMI=0.680/0.718/0.722/0.729/
# rank=5
# ARI=-0.026/-0.002/-0.002/0.013/
# AMI=-0.014/-0.002/-0.005/0.026/
# FMI=0.696/0.716/0.720/0.729/
# rank=6
# ARI=-0.030/-0.000/0.005/0.026/
# AMI=-0.014/0.008/0.009/0.035/
# FMI=0.524/0.709/0.722/0.729/
# rank=7
# ARI=-0.020/0.004/0.005/0.026/
# AMI=-0.014/-0.003/-0.011/0.032/
# FMI=0.654/0.717/0.720/0.729/
# rank=8
# ARI=-0.025/-0.001/-0.002/0.013/
# AMI=-0.014/-0.003/-0.005/0.009/
# FMI=0.615/0.713/0.720/0.729/
# rank=9
# ARI=-0.026/-0.000/0.005/0.015/
# AMI=-0.014/0.002/0.007/0.026/
# FMI=0.660/0.711/0.717/0.729/
# rank=10
# ARI=-0.042/0.005/0.009/0.040/
# AMI=-0.014/0.008/0.009/0.060/
# FMI=0.668/0.716/0.724/0.729/
#
#
# 		 Affinity: correlation
# 	 Linkage: complete
# rank=1
# ARI=-0.010/0.077/0.088/0.159/
# AMI=-0.006/0.048/0.057/0.108/
# FMI=0.513/0.587/0.578/0.669/
# rank=2
# ARI=-0.009/0.080/0.080/0.204/
# AMI=-0.006/0.044/0.048/0.131/
# FMI=0.516/0.594/0.597/0.697/
# rank=3
# ARI=-0.025/0.070/0.051/0.169/
# AMI=-0.000/0.053/0.063/0.148/
# FMI=0.519/0.585/0.583/0.698/
# rank=4
# ARI=-0.021/0.041/0.028/0.164/
# AMI=-0.010/0.032/0.022/0.112/
# FMI=0.512/0.587/0.565/0.686/
# rank=5
# ARI=-0.043/0.027/0.015/0.111/
# AMI=-0.007/0.032/0.024/0.133/
# FMI=0.513/0.584/0.580/0.690/
# rank=6
# ARI=-0.041/0.038/0.008/0.201/
# AMI=-0.007/0.034/0.035/0.121/
# FMI=0.518/0.582/0.575/0.649/
# rank=7
# ARI=-0.034/0.018/0.012/0.091/
# AMI=-0.007/0.006/-0.000/0.042/
# FMI=0.512/0.586/0.589/0.729/
# rank=8
# ARI=-0.021/0.037/0.025/0.202/
# AMI=-0.006/0.024/0.008/0.154/
# FMI=0.512/0.585/0.580/0.688/
# rank=9
# ARI=-0.033/0.016/0.004/0.111/
# AMI=-0.014/0.014/0.002/0.108/
# FMI=0.513/0.583/0.578/0.712/
# rank=10
# ARI=-0.013/0.004/-0.005/0.045/
# AMI=-0.009/-0.000/-0.005/0.015/
# FMI=0.511/0.569/0.541/0.717/
#
#
# 	 Linkage: average
# rank=1
# ARI=-0.035/-0.002/0.001/0.013/
# AMI=-0.014/0.008/0.009/0.044/
# FMI=0.683/0.716/0.722/0.729/
# rank=2
# ARI=-0.034/0.000/0.009/0.013/
# AMI=-0.014/0.004/0.009/0.019/
# FMI=0.666/0.716/0.726/0.729/
# rank=3
# ARI=-0.021/0.002/0.013/0.013/
# AMI=-0.011/0.006/0.009/0.016/
# FMI=0.688/0.721/0.729/0.729/
# rank=4
# ARI=-0.026/0.003/0.013/0.013/
# AMI=-0.014/0.004/0.009/0.009/
# FMI=0.663/0.718/0.729/0.729/
# rank=5
# ARI=-0.026/0.002/0.009/0.019/
# AMI=-0.014/0.004/0.009/0.026/
# FMI=0.662/0.715/0.723/0.729/
# rank=6
# ARI=-0.021/0.008/0.013/0.063/
# AMI=-0.014/0.006/0.009/0.040/
# FMI=0.670/0.721/0.729/0.729/
# rank=7
# ARI=-0.021/0.002/0.007/0.040/
# AMI=-0.014/0.006/0.009/0.055/
# FMI=0.688/0.719/0.722/0.729/
# rank=8
# ARI=-0.015/0.006/0.013/0.018/
# AMI=-0.014/0.001/0.009/0.009/
# FMI=0.696/0.721/0.729/0.729/
# rank=9
# ARI=-0.002/0.010/0.013/0.026/
# AMI=-0.014/-0.001/-0.001/0.032/
# FMI=0.710/0.723/0.720/0.729/
# rank=10
# ARI=-0.007/0.009/0.013/0.026/
# AMI=-0.014/0.002/0.009/0.032/
# FMI=0.702/0.723/0.727/0.729/
#
#
# 		 Affinity: rbf
# 	 Linkage: complete
# rank=1
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=2
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=3
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=4
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=5
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=6
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=7
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=8
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=9
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=10
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
#
#
# 	 Linkage: average
# rank=1
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=2
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=3
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=4
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=5
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=6
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=7
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=8
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=9
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/
# rank=10
# ARI=0.013/0.013/0.013/0.013/
# AMI=0.009/0.009/0.009/0.009/
# FMI=0.729/0.729/0.729/0.729/

# %%
MAX_NUM_THREADS = 8

import ctypes
mkl_rt = ctypes.CDLL('libmkl_rt.so')
#print(mkl_rt.mkl_get_max_threads())
mkl_get_max_threads = mkl_rt.mkl_get_max_threads
def mkl_set_num_threads(cores):
    mkl_rt.mkl_set_num_threads(ctypes.byref(ctypes.c_int(cores)))

mkl_set_num_threads(MAX_NUM_THREADS)
print(f'Number of threads was limited to {mkl_get_max_threads()}.')
# Out:
# Number of threads was limited to 8.

# %%
import os
import time
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy_tools
import loaders.eth80 as eth80
import loaders.smni_eeg as smni_eeg

from experiment_tools import temporal_sscal
from experiment_tools import kmeans_gmm_clustering_experiment
from experiment_tools import hac_clustering_experiment

import cluster.gtcd_contrasting

# %%
data_eth80_dirname = '/home/hariyuki/data/eth80/'
data_smni_dirname = '/home/hariyuki/data/eeg_smni/'

# %%
# load ETH80
data_eth80_path = os.path.join(data_eth80_dirname, 'eth80-cropped-close128')

image_shape = 32
Nclasses, Nobjects = 8, 10
Npixels = int(round(image_shape**2))

data, labels, classes = eth80.eth80_dataset(data_eth80_path, image_shape)
classes_reverse_dict = dict((y, x) for x, y in classes.items())
Nsamples, Nangles, _, _, Ncolors = data.shape
data = numpy_tools.reshape_np(data, [Nangles, -1, Ncolors], order='F', use_batch=True)
permutation = [0, 2, 1, 3]
data = np.transpose(data, permutation)

n = [Npixels, Nangles, Ncolors]

eth80_dataset = {
    'data': data,
    'n': n,
    'labels': labels,
    'classes': classes,
    'classes_reverse_dict': classes_reverse_dict
}

# %%
# load SMNI EEG
data_smni_path = os.path.join(data_smni_dirname, 'smni_eeg_processed.npz')
df = np.load(data_smni_path)
data, labels = df['data'], df['labels']

Nsubjects, Nchannels, Ntime, Nconditions = data.shape
permutation = [0, 2, 1, 3]
data = np.transpose(data, permutation)
n = [Ntime, Nchannels, Nconditions]

smni_dataset = {
    'data': data,
    'n': n,
    'labels': labels
}

# %%
datasets = {
    'eth80': eth80_dataset,
    'smni': smni_dataset
}
dataset_names = list(datasets.keys())

# %% [markdown]
# ## GTLD contrasting

# %%
commonRanks = 1+np.arange(5)
individualRanks = 1+np.arange(5)

# %%
save_results_dirname = '../results/clustering/'
os.makedirs(save_results_dirname, exist_ok=True)

#save_results_filename_ac = 'gica_contrasted_ac'
#save_results_filename_kg = 'gica_contrasted_kg'

Ntrials = 20
Ntrials_gtld = 10
np_random_seed = 720

np_random_state_gtld = 800
np.random.seed(np_random_state_gtld)
random_states_gtld = np.random.randint(1, 1000, Ntrials_gtld)
   
def preprocess_gtld(dataset, **kwargs):
    assert 'commonRank' in kwargs
    commonRank = kwargs['commonRank']
    assert 'individualRank' in kwargs
    individualRank = kwargs['individualRank']
    assert 'random_state' in kwargs
    random_state = kwargs['random_state']
    if 'sscal' in kwargs:
        sscal = kwargs['sscal']
    else:
        sscal = False
    n = dataset['n']
    contrasting = cluster.gtcd_contrasting.GTLDContrast(
        individualRank=individualRank,
        commonRank=commonRank,
        shapeObject=n,
        sourceModes=[0],
        method='als',
        nShortModes=None,
        constraintMethod='projected',
        fullModesConstraint=None,
        maxitnum=10,
        epsilon=1e-5,
        random_state=random_state
    )
    T = contrasting.fit_transform(dataset['data'].copy())
    if sscal:
        T = T - np.mean(T, axis=1, keepdims=True)
        T /= np.std(T, axis=1, keepdims=True, ddof=1)
    return T, dataset['labels']

result_ac, result_kg = [], []
affinity_names_old, linkage_old, dataset_names_old, n_clusters_old = None, None, None, None
for k_comr in range(len(commonRanks)):
    commonRank = commonRanks[k_comr]
    result_ac_crank, result_kg_crank = [], []
    for k_indr in range(len(individualRanks)):
        individualRank = individualRanks[k_indr]
        print(f'\t GTLD: crank={commonRank}, irank={individualRank}')
        result_ac_crank_irank, result_kg_crank_irank = [], []
        for k_trial in range(Ntrials_gtld):
            preprocess = {
                'eth80': lambda x: preprocess_gtld(
                    x,
                    commonRank=commonRank,
                    individualRank=individualRank,
                    random_state=random_states_gtld[k_trial]
                ),
                'smni': lambda x: preprocess_gtld(
                    x,
                    commonRank=commonRank,
                    individualRank=individualRank,
                    random_state=random_states_gtld[k_trial],
                    sscal=False
                )
            }
            result, affinity_names, linkage, dataset_names, n_clusters, df = hac_clustering_experiment(
                datasets,
                save_results_path=None,#save_results_path,
                preprocess=preprocess,
                verbose=True,
                return_datasets=True
            )
            if not ((k_comr == 0) and (k_indr == 0)):
                assert np.all([dataset_names[l] == dataset_names_old[l] for l in range(len(datasets))])
            dataset_names_old = dataset_names
            #result = np.empty([3, 4, 5])
            result_ac_crank_irank.append(result)

            result, dataset_names, random_states, clust_alg_names, n_clusters = (
                kmeans_gmm_clustering_experiment(
                    df,#datasets,
                    save_results_path=None,#save_results_path,
                    preprocess=None,#preprocess,
                    Ntrials=Ntrials,
                    np_random_seed=np_random_seed,
                    verbose=True
                )
            )
            assert dataset_names == dataset_names_old
            if not ((k_comr == 0) and (k_indr == 0)):
                assert np.all([random_states_old[l] == random_states[l] for l in range(Ntrials)])
            random_states_old = random_states
            #result = np.empty([8, 5])
            result_kg_crank_irank.append(result)
            
            np.savez_compressed(
                'gtld_contrasted_clustering_temporal',
                result_ac=result_ac,
                result_kg=result_kg,
                result_ac_crank=result_ac_crank,
                result_kg_crank=result_kg_crank,
                result_ac_crank_irank=result_ac_crank_irank,
                result_kg_crank_irank=result_kg_crank_irank,
            )
            
            
        result_ac_crank.append(result_ac_crank_irank)
        result_kg_crank.append(result_kg_crank_irank)
    result_ac.append(result_ac_crank)
    result_kg.append(result_kg_crank)
result_ac, result_kg = np.array(result_ac), np.array(result_kg)
np.savez_compressed(
    'gtld_contrasted_clustering',
    result_ac=result_ac,
    result_kg=result_kg,
    random_states=random_states,
    clust_alg_names=clust_alg_names,
    Ntrials=Ntrials,
    np_random_seed=np_random_seed,
    affinity_names=affinity_names,
    linkage=linkage,
    dataset_names=dataset_names,
    random_states_gtld=random_states_gtld,
    np_random_state_gtld=np_random_state_gtld
)
# Out:
# 	 GTLD: crank=1, irank=1
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.397 AMI=0.676 FMI=0.540
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.379 AMI=0.661 FMI=0.521
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.410 AMI=0.626 FMI=0.504
# 	 Linkage: average
# ARI=0.367 AMI=0.674 FMI=0.520
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.395 AMI=0.672 FMI=0.539
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.371 AMI=0.678 FMI=0.525
# 	 Linkage: average
# ARI=0.345 AMI=0.638 FMI=0.500
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.379 AMI=0.661 FMI=0.521
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.016 AMI=0.004 FMI=0.538
# 	 Linkage: average
# ARI=-0.007 AMI=-0.006 FMI=0.520
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.024 AMI=0.000 FMI=0.598
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.005 AMI=-0.002 FMI=0.513
# 	 Linkage: average
# ARI=-0.027 AMI=0.022 FMI=0.568
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.379/0.393/0.386/0.432
# AMI=0.586/0.598/0.593/0.632
# FMI=0.472/0.485/0.479/0.521
# 	 GMM min/mean/median/max
# ARI=0.361/0.434/0.426/0.523
# AMI=0.580/0.623/0.628/0.680
# FMI=0.455/0.519/0.516/0.587
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.039
# AMI=0.009/0.009/0.009/0.013
# FMI=0.697/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.033/0.039/0.039
# AMI=-0.001/0.011/0.013/0.013
# FMI=0.697/0.705/0.697/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.297 AMI=0.456 FMI=0.392
# 	 Linkage: average
# ARI=0.365 AMI=0.545 FMI=0.458
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.285 AMI=0.468 FMI=0.387
# 	 Linkage: average
# ARI=0.326 AMI=0.562 FMI=0.446
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.290 AMI=0.547 FMI=0.442
# 	 Linkage: average
# ARI=0.297 AMI=0.595 FMI=0.467
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.272 AMI=0.469 FMI=0.379
# 	 Linkage: average
# ARI=0.309 AMI=0.572 FMI=0.455
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.285 AMI=0.538 FMI=0.436
# 	 Linkage: average
# ARI=0.297 AMI=0.595 FMI=0.467
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.285 AMI=0.468 FMI=0.387
# 	 Linkage: average
# ARI=0.326 AMI=0.562 FMI=0.446
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.034 AMI=0.014 FMI=0.541
# 	 Linkage: average
# ARI=0.037 AMI=0.005 FMI=0.644
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.185 AMI=0.108 FMI=0.631
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.052 AMI=0.014 FMI=0.635
# 	 Linkage: average
# ARI=0.045 AMI=0.010 FMI=0.652
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.294/0.349/0.355/0.386
# AMI=0.466/0.506/0.507/0.537
# FMI=0.394/0.435/0.437/0.464
# 	 GMM min/mean/median/max
# ARI=0.205/0.315/0.325/0.399
# AMI=0.372/0.480/0.494/0.529
# FMI=0.305/0.408/0.420/0.473
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.026/0.013/0.045
# AMI=0.009/0.018/0.009/0.031
# FMI=0.716/0.724/0.729/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.023 AMI=0.002 FMI=0.570
# 	 Linkage: average
# ARI=-0.012 AMI=-0.007 FMI=0.596
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.031 AMI=0.025 FMI=0.579
# 	 Linkage: average
# ARI=-0.016 AMI=-0.006 FMI=0.590
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.321/0.345/0.345/0.398
# AMI=0.474/0.497/0.499/0.544
# FMI=0.412/0.433/0.434/0.477
# 	 GMM min/mean/median/max
# ARI=0.287/0.353/0.354/0.394
# AMI=0.453/0.521/0.523/0.563
# FMI=0.398/0.447/0.447/0.476
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.013/0.010/0.013/0.013
# AMI=-0.006/0.007/0.009/0.009
# FMI=0.570/0.713/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.023/0.027/0.027
# AMI=-0.006/0.003/0.002/0.009
# FMI=0.698/0.705/0.698/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.355 AMI=0.602 FMI=0.485
# 	 Linkage: average
# ARI=0.422 AMI=0.682 FMI=0.547
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.431 AMI=0.665 FMI=0.540
# 	 Linkage: average
# ARI=0.426 AMI=0.659 FMI=0.537
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.350 AMI=0.595 FMI=0.481
# 	 Linkage: average
# ARI=0.416 AMI=0.662 FMI=0.536
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.365 AMI=0.498 FMI=0.448
# 	 Linkage: average
# ARI=0.405 AMI=0.564 FMI=0.493
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.394 AMI=0.563 FMI=0.482
# 	 Linkage: average
# ARI=0.416 AMI=0.662 FMI=0.536
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.431 AMI=0.665 FMI=0.540
# 	 Linkage: average
# ARI=0.426 AMI=0.659 FMI=0.537
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.015 AMI=-0.004 FMI=0.621
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.552
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.034 AMI=0.019 FMI=0.666
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.003 AMI=-0.008 FMI=0.623
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.391/0.444/0.445/0.482
# AMI=0.562/0.583/0.584/0.609
# FMI=0.479/0.517/0.519/0.548
# 	 GMM min/mean/median/max
# ARI=0.358/0.408/0.403/0.462
# AMI=0.526/0.596/0.604/0.637
# FMI=0.471/0.503/0.506/0.535
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.039
# AMI=0.009/0.009/0.009/0.013
# FMI=0.697/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.031/0.039/0.039
# AMI=-0.001/0.010/0.013/0.013
# FMI=0.697/0.707/0.697/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.352 AMI=0.564 FMI=0.466
# 	 Linkage: average
# ARI=0.294 AMI=0.520 FMI=0.433
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.360 AMI=0.524 FMI=0.452
# 	 Linkage: average
# ARI=0.373 AMI=0.607 FMI=0.499
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.322 AMI=0.498 FMI=0.417
# 	 Linkage: average
# ARI=0.389 AMI=0.644 FMI=0.512
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.302 AMI=0.500 FMI=0.408
# 	 Linkage: average
# ARI=0.302 AMI=0.530 FMI=0.441
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.460 AMI=0.636 FMI=0.544
# 	 Linkage: average
# ARI=0.389 AMI=0.644 FMI=0.512
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.360 AMI=0.524 FMI=0.452
# 	 Linkage: average
# ARI=0.373 AMI=0.607 FMI=0.499
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.016 AMI=0.016 FMI=0.544
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.105 AMI=0.053 FMI=0.590
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.044 AMI=0.035 FMI=0.536
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.349/0.404/0.410/0.433
# AMI=0.522/0.563/0.569/0.582
# FMI=0.438/0.486/0.492/0.512
# 	 GMM min/mean/median/max
# ARI=0.325/0.410/0.418/0.463
# AMI=0.518/0.565/0.571/0.613
# FMI=0.447/0.491/0.498/0.535
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.343 AMI=0.502 FMI=0.429
# 	 Linkage: average
# ARI=0.357 AMI=0.597 FMI=0.489
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.413 AMI=0.571 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.612 FMI=0.500
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.354 AMI=0.574 FMI=0.467
# 	 Linkage: average
# ARI=0.378 AMI=0.584 FMI=0.490
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.392 AMI=0.546 FMI=0.472
# 	 Linkage: average
# ARI=0.318 AMI=0.559 FMI=0.452
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.354 AMI=0.574 FMI=0.467
# 	 Linkage: average
# ARI=0.378 AMI=0.584 FMI=0.490
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.413 AMI=0.571 FMI=0.494
# 	 Linkage: average
# ARI=0.341 AMI=0.612 FMI=0.500
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.026 AMI=0.002 FMI=0.663
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.378/0.408/0.409/0.432
# AMI=0.541/0.556/0.555/0.581
# FMI=0.464/0.488/0.488/0.509
# 	 GMM min/mean/median/max
# ARI=0.317/0.371/0.366/0.418
# AMI=0.490/0.524/0.518/0.565
# FMI=0.415/0.458/0.452/0.498
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.033/0.039/0.039
# AMI=0.009/0.012/0.013/0.015
# FMI=0.697/0.706/0.697/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.370 AMI=0.594 FMI=0.487
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.361 AMI=0.566 FMI=0.466
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.442 AMI=0.600 FMI=0.529
# 	 Linkage: average
# ARI=0.430 AMI=0.640 FMI=0.533
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.369 AMI=0.584 FMI=0.473
# 	 Linkage: average
# ARI=0.362 AMI=0.627 FMI=0.516
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.442 AMI=0.600 FMI=0.529
# 	 Linkage: average
# ARI=0.411 AMI=0.610 FMI=0.518
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.361 AMI=0.566 FMI=0.466
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.051 AMI=0.057 FMI=0.543
# 	 Linkage: average
# ARI=-0.008 AMI=0.015 FMI=0.531
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.030 AMI=0.042 FMI=0.580
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.005 FMI=0.512
# 	 Linkage: average
# ARI=-0.007 AMI=-0.006 FMI=0.512
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.358/0.431/0.430/0.463
# AMI=0.556/0.580/0.578/0.600
# FMI=0.454/0.507/0.505/0.533
# 	 GMM min/mean/median/max
# ARI=0.359/0.406/0.411/0.491
# AMI=0.540/0.579/0.575/0.624
# FMI=0.452/0.489/0.494/0.554
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.018
# AMI=-0.001/0.008/0.009/0.009
# FMI=0.719/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.031/0.039/0.039
# AMI=-0.001/0.011/0.013/0.013
# FMI=0.697/0.707/0.697/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.386 AMI=0.598 FMI=0.491
# 	 Linkage: average
# ARI=0.366 AMI=0.662 FMI=0.523
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.355 AMI=0.554 FMI=0.451
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.481 AMI=0.619 FMI=0.547
# 	 Linkage: average
# ARI=0.370 AMI=0.584 FMI=0.484
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.360 AMI=0.548 FMI=0.457
# 	 Linkage: average
# ARI=0.331 AMI=0.602 FMI=0.481
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.481 AMI=0.619 FMI=0.547
# 	 Linkage: average
# ARI=0.370 AMI=0.584 FMI=0.484
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.355 AMI=0.554 FMI=0.451
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.083 AMI=0.038 FMI=0.580
# 	 Linkage: average
# ARI=0.034 AMI=0.004 FMI=0.652
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.041 AMI=0.018 FMI=0.546
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.016 AMI=-0.002 FMI=0.538
# 	 Linkage: average
# ARI=0.064 AMI=0.025 FMI=0.669
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.359/0.427/0.432/0.473
# AMI=0.564/0.594/0.600/0.633
# FMI=0.452/0.509/0.515/0.541
# 	 GMM min/mean/median/max
# ARI=0.311/0.409/0.419/0.483
# AMI=0.499/0.580/0.580/0.639
# FMI=0.412/0.492/0.498/0.546
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.029/0.029/0.045
# AMI=0.009/0.020/0.020/0.031
# FMI=0.716/0.722/0.722/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.409 AMI=0.613 FMI=0.512
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.388 AMI=0.610 FMI=0.505
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.428 AMI=0.572 FMI=0.515
# 	 Linkage: average
# ARI=0.382 AMI=0.590 FMI=0.494
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.315 AMI=0.488 FMI=0.405
# 	 Linkage: average
# ARI=0.416 AMI=0.558 FMI=0.505
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.428 AMI=0.572 FMI=0.515
# 	 Linkage: average
# ARI=0.382 AMI=0.590 FMI=0.494
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.388 AMI=0.610 FMI=0.505
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.020 AMI=-0.003 FMI=0.579
# 	 Linkage: average
# ARI=-0.029 AMI=0.015 FMI=0.576
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.019 AMI=-0.005 FMI=0.598
# 	 Linkage: average
# ARI=0.018 AMI=-0.004 FMI=0.690
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.022 AMI=0.021 FMI=0.558
# 	 Linkage: average
# ARI=-0.021 AMI=0.004 FMI=0.555
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.351/0.405/0.411/0.427
# AMI=0.510/0.557/0.561/0.570
# FMI=0.441/0.486/0.490/0.502
# 	 GMM min/mean/median/max
# ARI=0.322/0.401/0.406/0.455
# AMI=0.508/0.560/0.559/0.613
# FMI=0.420/0.484/0.487/0.532
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.027
# AMI=-0.001/0.008/0.009/0.009
# FMI=0.698/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.023/0.027/0.027
# AMI=-0.001/0.003/0.002/0.009
# FMI=0.698/0.706/0.698/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.396 AMI=0.545 FMI=0.476
# 	 Linkage: average
# ARI=0.340 AMI=0.561 FMI=0.449
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.464 AMI=0.612 FMI=0.536
# 	 Linkage: average
# ARI=0.426 AMI=0.659 FMI=0.537
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.311 AMI=0.562 FMI=0.449
# 	 Linkage: average
# ARI=0.389 AMI=0.644 FMI=0.512
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.367 AMI=0.539 FMI=0.456
# 	 Linkage: average
# ARI=0.299 AMI=0.582 FMI=0.466
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.468 AMI=0.619 FMI=0.542
# 	 Linkage: average
# ARI=0.389 AMI=0.644 FMI=0.512
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.464 AMI=0.612 FMI=0.536
# 	 Linkage: average
# ARI=0.426 AMI=0.659 FMI=0.537
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.102 AMI=0.048 FMI=0.600
# 	 Linkage: average
# ARI=-0.027 AMI=0.022 FMI=0.568
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.005 AMI=-0.004 FMI=0.545
# 	 Linkage: average
# ARI=-0.031 AMI=0.025 FMI=0.579
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.008 AMI=-0.006 FMI=0.511
# 	 Linkage: average
# ARI=-0.006 AMI=-0.007 FMI=0.537
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.355/0.405/0.407/0.440
# AMI=0.524/0.556/0.552/0.585
# FMI=0.443/0.484/0.484/0.516
# 	 GMM min/mean/median/max
# ARI=0.321/0.402/0.410/0.467
# AMI=0.481/0.553/0.553/0.617
# FMI=0.409/0.482/0.483/0.530
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.018
# AMI=-0.001/0.008/0.009/0.009
# FMI=0.719/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.031/0.035/0.035
# AMI=0.000/0.011/0.013/0.013
# FMI=0.707/0.710/0.707/0.729
# 	 GTLD: crank=1, irank=2
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.440 AMI=0.586 FMI=0.515
# 	 Linkage: average
# ARI=0.411 AMI=0.616 FMI=0.507
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.325 AMI=0.536 FMI=0.430
# 	 Linkage: average
# ARI=0.431 AMI=0.631 FMI=0.524
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.438 AMI=0.657 FMI=0.531
# 	 Linkage: average
# ARI=0.361 AMI=0.656 FMI=0.515
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.493 AMI=0.620 FMI=0.559
# 	 Linkage: average
# ARI=0.352 AMI=0.626 FMI=0.505
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.428 AMI=0.638 FMI=0.523
# 	 Linkage: average
# ARI=0.373 AMI=0.603 FMI=0.492
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.325 AMI=0.536 FMI=0.430
# 	 Linkage: average
# ARI=0.431 AMI=0.631 FMI=0.524
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.035 AMI=0.006 FMI=0.591
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.022 AMI=-0.003 FMI=0.653
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.000 AMI=-0.007 FMI=0.579
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.353/0.419/0.422/0.490
# AMI=0.540/0.566/0.563/0.613
# FMI=0.452/0.494/0.495/0.554
# 	 GMM min/mean/median/max
# ARI=0.344/0.426/0.420/0.481
# AMI=0.536/0.575/0.584/0.615
# FMI=0.451/0.504/0.499/0.548
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.016/0.018/0.018
# AMI=-0.001/0.002/-0.001/0.009
# FMI=0.719/0.722/0.719/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.398 AMI=0.555 FMI=0.482
# 	 Linkage: average
# ARI=0.406 AMI=0.621 FMI=0.509
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.410 AMI=0.565 FMI=0.489
# 	 Linkage: average
# ARI=0.369 AMI=0.667 FMI=0.526
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.371 AMI=0.591 FMI=0.485
# 	 Linkage: average
# ARI=0.333 AMI=0.602 FMI=0.492
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.323 AMI=0.504 FMI=0.426
# 	 Linkage: average
# ARI=0.354 AMI=0.605 FMI=0.489
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.423 AMI=0.637 FMI=0.523
# 	 Linkage: average
# ARI=0.333 AMI=0.602 FMI=0.492
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.410 AMI=0.565 FMI=0.489
# 	 Linkage: average
# ARI=0.369 AMI=0.667 FMI=0.526
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.022 AMI=0.031 FMI=0.562
# 	 Linkage: average
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.019 AMI=0.002 FMI=0.549
# 	 Linkage: average
# ARI=-0.026 AMI=0.002 FMI=0.663
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.094 AMI=0.041 FMI=0.623
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.335/0.397/0.405/0.428
# AMI=0.511/0.558/0.561/0.583
# FMI=0.438/0.480/0.486/0.506
# 	 GMM min/mean/median/max
# ARI=0.314/0.405/0.406/0.470
# AMI=0.507/0.570/0.569/0.631
# FMI=0.411/0.489/0.488/0.540
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.030/0.045/0.045
# AMI=0.009/0.021/0.031/0.031
# FMI=0.716/0.722/0.716/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.417 AMI=0.614 FMI=0.513
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.480 AMI=0.637 FMI=0.553
# 	 Linkage: average
# ARI=0.380 AMI=0.627 FMI=0.506
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.425 AMI=0.568 FMI=0.501
# 	 Linkage: average
# ARI=0.456 AMI=0.624 FMI=0.532
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.480 AMI=0.637 FMI=0.553
# 	 Linkage: average
# ARI=0.377 AMI=0.606 FMI=0.500
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.001 AMI=-0.007 FMI=0.615
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.029 AMI=0.015 FMI=0.576
# 	 Linkage: average
# ARI=0.018 AMI=-0.001 FMI=0.719
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.014 AMI=-0.005 FMI=0.544
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.355/0.429/0.416/0.479
# AMI=0.531/0.590/0.592/0.622
# FMI=0.442/0.507/0.503/0.547
# 	 GMM min/mean/median/max
# ARI=0.340/0.412/0.415/0.470
# AMI=0.508/0.579/0.580/0.625
# FMI=0.426/0.493/0.500/0.540
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.045
# AMI=0.009/0.010/0.009/0.031
# FMI=0.716/0.728/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.037/0.059/0.059
# AMI=-0.014/0.028/0.048/0.048
# FMI=0.715/0.720/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.431 AMI=0.631 FMI=0.524
# 	 Linkage: average
# ARI=0.389 AMI=0.683 FMI=0.544
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.404 AMI=0.629 FMI=0.507
# 	 Linkage: average
# ARI=0.389 AMI=0.683 FMI=0.544
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.371 AMI=0.571 FMI=0.471
# 	 Linkage: average
# ARI=0.361 AMI=0.656 FMI=0.515
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.431 AMI=0.631 FMI=0.524
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.382 AMI=0.600 FMI=0.490
# 	 Linkage: average
# ARI=0.347 AMI=0.623 FMI=0.500
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.404 AMI=0.629 FMI=0.507
# 	 Linkage: average
# ARI=0.389 AMI=0.683 FMI=0.544
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.018 AMI=-0.001 FMI=0.719
# 	 Linkage: average
# ARI=0.018 AMI=-0.001 FMI=0.719
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.003 AMI=0.060 FMI=0.552
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.025 AMI=0.038 FMI=0.569
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.393/0.429/0.430/0.460
# AMI=0.584/0.620/0.624/0.641
# FMI=0.483/0.515/0.519/0.541
# 	 GMM min/mean/median/max
# ARI=0.393/0.455/0.446/0.507
# AMI=0.580/0.621/0.623/0.670
# FMI=0.483/0.531/0.526/0.573
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.028/0.013/0.111
# AMI=0.009/0.019/0.009/0.074
# FMI=0.572/0.706/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.015/0.018/0.018
# AMI=-0.014/-0.004/-0.001/-0.001
# FMI=0.719/0.719/0.719/0.720
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.418 AMI=0.565 FMI=0.497
# 	 Linkage: average
# ARI=0.453 AMI=0.648 FMI=0.546
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.403 AMI=0.640 FMI=0.517
# 	 Linkage: average
# ARI=0.434 AMI=0.633 FMI=0.529
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.397 AMI=0.573 FMI=0.482
# 	 Linkage: average
# ARI=0.364 AMI=0.603 FMI=0.496
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.311 AMI=0.540 FMI=0.446
# 	 Linkage: average
# ARI=0.290 AMI=0.523 FMI=0.435
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.397 AMI=0.573 FMI=0.482
# 	 Linkage: average
# ARI=0.364 AMI=0.603 FMI=0.496
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.403 AMI=0.640 FMI=0.517
# 	 Linkage: average
# ARI=0.434 AMI=0.633 FMI=0.529
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.021 AMI=-0.001 FMI=0.605
# 	 Linkage: average
# ARI=0.071 AMI=0.035 FMI=0.686
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.008 AMI=0.003 FMI=0.520
# 	 Linkage: average
# ARI=0.015 AMI=-0.005 FMI=0.645
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.084 AMI=0.034 FMI=0.615
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.398/0.451/0.446/0.517
# AMI=0.544/0.595/0.597/0.642
# FMI=0.473/0.522/0.520/0.578
# 	 GMM min/mean/median/max
# ARI=0.358/0.451/0.451/0.527
# AMI=0.533/0.590/0.604/0.638
# FMI=0.453/0.522/0.528/0.582
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.043/0.059/0.059
# AMI=0.009/0.034/0.048/0.048
# FMI=0.715/0.720/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.366 AMI=0.662 FMI=0.523
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.439 AMI=0.637 FMI=0.533
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.472 AMI=0.670 FMI=0.557
# 	 Linkage: average
# ARI=0.459 AMI=0.625 FMI=0.536
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.485 AMI=0.608 FMI=0.550
# 	 Linkage: average
# ARI=0.472 AMI=0.654 FMI=0.557
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.493 AMI=0.635 FMI=0.563
# 	 Linkage: average
# ARI=0.453 AMI=0.638 FMI=0.540
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.439 AMI=0.637 FMI=0.533
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.002 AMI=-0.009 FMI=0.656
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.029 AMI=0.006 FMI=0.603
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.008 AMI=-0.002 FMI=0.536
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.380/0.437/0.435/0.490
# AMI=0.566/0.594/0.582/0.627
# FMI=0.475/0.514/0.507/0.555
# 	 GMM min/mean/median/max
# ARI=0.313/0.410/0.414/0.505
# AMI=0.489/0.583/0.582/0.639
# FMI=0.412/0.495/0.505/0.566
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.036/0.031/0.059
# AMI=0.009/0.026/0.015/0.048
# FMI=0.715/0.720/0.717/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.383 AMI=0.571 FMI=0.475
# 	 Linkage: average
# ARI=0.362 AMI=0.652 FMI=0.517
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.358 AMI=0.557 FMI=0.455
# 	 Linkage: average
# ARI=0.389 AMI=0.658 FMI=0.533
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.506 AMI=0.644 FMI=0.569
# 	 Linkage: average
# ARI=0.459 AMI=0.651 FMI=0.552
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.425 AMI=0.611 FMI=0.512
# 	 Linkage: average
# ARI=0.392 AMI=0.637 FMI=0.521
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.506 AMI=0.644 FMI=0.569
# 	 Linkage: average
# ARI=0.459 AMI=0.651 FMI=0.552
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.358 AMI=0.557 FMI=0.455
# 	 Linkage: average
# ARI=0.389 AMI=0.658 FMI=0.533
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.026 AMI=0.003 FMI=0.566
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.010 AMI=0.037 FMI=0.550
# 	 Linkage: average
# ARI=-0.026 AMI=0.026 FMI=0.698
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.023 AMI=-0.002 FMI=0.680
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.332/0.393/0.399/0.490
# AMI=0.528/0.584/0.592/0.627
# FMI=0.438/0.485/0.493/0.555
# 	 GMM min/mean/median/max
# ARI=0.330/0.407/0.401/0.486
# AMI=0.537/0.585/0.580/0.631
# FMI=0.428/0.492/0.490/0.549
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.044/0.044/0.044/0.044
# AMI=0.039/0.039/0.039/0.039
# FMI=0.536/0.536/0.536/0.536
# 	 GMM min/mean/median/max
# ARI=0.013/0.040/0.044/0.045
# AMI=0.009/0.037/0.039/0.047
# FMI=0.536/0.574/0.537/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.327 AMI=0.537 FMI=0.432
# 	 Linkage: average
# ARI=0.415 AMI=0.702 FMI=0.557
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.427 AMI=0.584 FMI=0.504
# 	 Linkage: average
# ARI=0.397 AMI=0.654 FMI=0.529
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.387 AMI=0.642 FMI=0.518
# 	 Linkage: average
# ARI=0.387 AMI=0.642 FMI=0.518
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.356 AMI=0.571 FMI=0.457
# 	 Linkage: average
# ARI=0.415 AMI=0.702 FMI=0.557
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.438 AMI=0.653 FMI=0.535
# 	 Linkage: average
# ARI=0.413 AMI=0.670 FMI=0.545
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.427 AMI=0.584 FMI=0.504
# 	 Linkage: average
# ARI=0.397 AMI=0.654 FMI=0.529
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.002 AMI=-0.006 FMI=0.573
# 	 Linkage: average
# ARI=0.006 AMI=-0.007 FMI=0.622
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.008 AMI=0.007 FMI=0.524
# 	 Linkage: average
# ARI=-0.005 AMI=-0.011 FMI=0.693
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.006 AMI=-0.007 FMI=0.622
# 	 Linkage: average
# ARI=-0.011 AMI=-0.007 FMI=0.563
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.388/0.437/0.441/0.496
# AMI=0.527/0.593/0.588/0.645
# FMI=0.463/0.513/0.512/0.562
# 	 GMM min/mean/median/max
# ARI=0.367/0.419/0.420/0.464
# AMI=0.533/0.577/0.573/0.629
# FMI=0.458/0.499/0.498/0.541
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.022/0.024/0.031
# AMI=-0.001/0.011/0.012/0.015
# FMI=0.717/0.722/0.718/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.332 AMI=0.540 FMI=0.440
# 	 Linkage: average
# ARI=0.329 AMI=0.617 FMI=0.488
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.410 AMI=0.642 FMI=0.519
# 	 Linkage: average
# ARI=0.331 AMI=0.617 FMI=0.491
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.365 AMI=0.548 FMI=0.480
# 	 Linkage: average
# ARI=0.307 AMI=0.464 FMI=0.437
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.344 AMI=0.496 FMI=0.456
# 	 Linkage: average
# ARI=0.224 AMI=0.402 FMI=0.385
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.365 AMI=0.548 FMI=0.480
# 	 Linkage: average
# ARI=0.307 AMI=0.464 FMI=0.437
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.410 AMI=0.642 FMI=0.519
# 	 Linkage: average
# ARI=0.331 AMI=0.617 FMI=0.491
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.010 AMI=-0.005 FMI=0.520
# 	 Linkage: average
# ARI=0.037 AMI=0.005 FMI=0.644
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.090 AMI=0.070 FMI=0.558
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.038 AMI=0.008 FMI=0.584
# 	 Linkage: average
# ARI=0.001 AMI=-0.007 FMI=0.593
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.315/0.408/0.406/0.487
# AMI=0.488/0.568/0.574/0.622
# FMI=0.409/0.486/0.486/0.553
# 	 GMM min/mean/median/max
# ARI=0.320/0.404/0.423/0.507
# AMI=0.505/0.568/0.571/0.639
# FMI=0.420/0.486/0.497/0.567
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.043/0.059/0.059
# AMI=0.009/0.034/0.048/0.048
# FMI=0.715/0.720/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.432 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.414 AMI=0.615 FMI=0.506
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.431 AMI=0.656 FMI=0.534
# 	 Linkage: average
# ARI=0.351 AMI=0.594 FMI=0.483
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.390 AMI=0.533 FMI=0.474
# 	 Linkage: average
# ARI=0.408 AMI=0.585 FMI=0.500
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.439 AMI=0.588 FMI=0.512
# 	 Linkage: average
# ARI=0.373 AMI=0.610 FMI=0.501
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.414 AMI=0.615 FMI=0.506
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.015 AMI=-0.005 FMI=0.645
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.022 AMI=0.043 FMI=0.566
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.003 AMI=0.030 FMI=0.534
# 	 Linkage: average
# ARI=0.015 AMI=-0.005 FMI=0.672
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.399/0.430/0.423/0.487
# AMI=0.561/0.580/0.575/0.618
# FMI=0.478/0.504/0.497/0.553
# 	 GMM min/mean/median/max
# ARI=0.312/0.413/0.420/0.481
# AMI=0.477/0.574/0.573/0.615
# FMI=0.398/0.492/0.497/0.545
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.013/0.018/0.018
# AMI=-0.014/-0.003/-0.001/0.009
# FMI=0.719/0.721/0.719/0.729
# 	 GTLD: crank=1, irank=3
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.425 AMI=0.628 FMI=0.518
# 	 Linkage: average
# ARI=0.431 AMI=0.631 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.440 AMI=0.633 FMI=0.528
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.357 AMI=0.652 FMI=0.511
# 	 Linkage: average
# ARI=0.361 AMI=0.656 FMI=0.515
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.467 AMI=0.649 FMI=0.550
# 	 Linkage: average
# ARI=0.397 AMI=0.690 FMI=0.539
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.382 AMI=0.600 FMI=0.490
# 	 Linkage: average
# ARI=0.352 AMI=0.626 FMI=0.505
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.440 AMI=0.633 FMI=0.528
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.018 AMI=-0.002 FMI=0.556
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.219 AMI=0.138 FMI=0.638
# 	 Linkage: average
# ARI=0.007 AMI=-0.009 FMI=0.691
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.116 AMI=0.060 FMI=0.598
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.364/0.433/0.428/0.541
# AMI=0.547/0.614/0.625/0.693
# FMI=0.459/0.515/0.514/0.603
# 	 GMM min/mean/median/max
# ARI=0.372/0.437/0.424/0.571
# AMI=0.574/0.620/0.623/0.720
# FMI=0.468/0.521/0.517/0.628
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=-0.002/0.014/0.013/0.044
# AMI=-0.004/0.010/0.009/0.039
# FMI=0.515/0.678/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.336 AMI=0.567 FMI=0.456
# 	 Linkage: average
# ARI=0.431 AMI=0.631 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.404 AMI=0.626 FMI=0.504
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.399 AMI=0.617 FMI=0.503
# 	 Linkage: average
# ARI=0.347 AMI=0.625 FMI=0.507
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.377 AMI=0.591 FMI=0.471
# 	 Linkage: average
# ARI=0.397 AMI=0.690 FMI=0.539
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.436 AMI=0.653 FMI=0.533
# 	 Linkage: average
# ARI=0.409 AMI=0.640 FMI=0.519
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.404 AMI=0.626 FMI=0.504
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.063 AMI=0.040 FMI=0.705
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.003 AMI=0.030 FMI=0.538
# 	 Linkage: average
# ARI=0.011 AMI=-0.007 FMI=0.681
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.093 AMI=0.044 FMI=0.587
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.380/0.420/0.415/0.466
# AMI=0.547/0.599/0.603/0.640
# FMI=0.471/0.502/0.495/0.539
# 	 GMM min/mean/median/max
# ARI=0.349/0.451/0.453/0.562
# AMI=0.549/0.614/0.616/0.673
# FMI=0.446/0.527/0.530/0.616
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.014/0.015/0.018
# AMI=-0.014/-0.001/-0.001/0.009
# FMI=0.719/0.722/0.720/0.729
# 			 eth80

# %%
from td.utils import reshape, prodTenMat

import group_tcd
#import gtcd_jit as gtcd
import gtcd

maxitnum = 200
epsilon = 1e-8
verbose = True

_maxInnerIt = 15
_tolRes = 1e-8
_tolGrad = 1e-8
_tolSwamp = 1e-8

def alsM(a, x0, cdN, ldN, tdN, maxitnum, constraints, verbose):
    return gtcd.tcd(
        a, x0=x0, canonical_dict=cdN, lro_dict=ldN, tucker_dict=tdN, maxitnum=maxitnum, 
        tolRes=_tolRes, tolGrad=_tolGrad, tolSwamp=_tolSwamp, method='als', verbose=verbose, 
        regTGD=None, regPGD=None, doSA=0, constraints=constraints
    )
        
groupConstraintMethod = 'projected'


source_mode = [1]
nShortModes = 1
fullModesConstraint = None
modeSizeFirstPriority = True

individualRank = 3
commonRank = 5
random_state = 576

shape = [-1] + list(n)
T = reshape(data, shape)
transposition = list(range(1, len(n)+1)) + [0]
T = np.transpose(T, transposition)
T = T.astype(np.float32)
n = T.shape
groupConstraint = group_tcd.group_constraint(
    n, source_mode, groupConstraintMethod
)
normT = np.linalg.norm(T)
T /= normT
cdN = None
P = len(T.shape)-nShortModes

ldN = {
    'L': [individualRank]*n[-1],
    'P': P,
    'fullModesConstraint': fullModesConstraint
}
r = np.zeros([1, len(T.shape)])
r[0, :-1] = commonRank
if modeSizeFirstPriority:
    r[0, :-1] = np.minimum(r[0, :-1], n[:-1]) 
# last mode - group axis
r[:, -1] = n[-1]
tdN = {
    'r': r.astype('i')
}
x0 = None
np.random.seed(random_state)
#tic = time.clock()
cdN, ldN, tdN, info = alsM(
    T, x0, cdN, ldN, tdN, maxitnum, groupConstraint, verbose
)
#toc = time.clock()
#self.timesEstimate = toc-tic
indCommon = commonRank
fmc = fullModesConstraint
contrasted = [None]*len(n)

del ldN['E']
contrastedT = gtcd.recover(n, lro_dict=ldN)
permutation = np.roll(np.arange(T.ndim), 1)
contrastedT = np.transpose(contrastedT, permutation)
groupT = gtcd.recover(n, tucker_dict=tdN)
groupT = np.transpose(groupT, permutation)

# %%
np.savez_compressed(
    'example_gtld_eth80.npz',
    groupT=groupT,
    contrastedT=contrastedT,
    individualRank=individualRank,
    commonRank=commonRank,
    random_state=random_state
)

# %%
from PIL import Image

nframe = 25
nobj = 71

def get_image(tensor, nobj, nframe):
    image = tensor[nobj, :, nframe, :]
    image = image - image.min()
    image = image / image.max()
    image = reshape(image, [32, 32, 3])
    image *= 255.
    return image.astype(np.uint8)

image = get_image(data, nobj, nframe)
plt.imshow(image)
Image.fromarray(image).save('original.jpg')
plt.show()
image = get_image(groupT, nobj, nframe)
plt.imshow(image)
Image.fromarray(image).save('gtld_common.jpg')
plt.show()
image = get_image(contrastedT, nobj, nframe)
plt.imshow(image)
Image.fromarray(image).save('gtld_individual.jpg')
plt.show()

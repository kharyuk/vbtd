# %%
MAX_NUM_THREADS = 10

import ctypes
mkl_rt = ctypes.CDLL('libmkl_rt.so')
#print(mkl_rt.mkl_get_max_threads())
mkl_get_max_threads = mkl_rt.mkl_get_max_threads
def mkl_set_num_threads(cores):
    mkl_rt.mkl_set_num_threads(ctypes.byref(ctypes.c_int(cores)))

mkl_set_num_threads(MAX_NUM_THREADS)
print(f'Number of threads was limited to {mkl_get_max_threads()}.')
# Out:
# Number of threads was limited to 10.

# %%
import os
import time
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy_tools
import loaders.eth80 as eth80
import loaders.smni_eeg as smni_eeg

from experiment_tools import temporal_sscal
from experiment_tools import kmeans_gmm_clustering_experiment
from experiment_tools import hac_clustering_experiment

import cluster.gtcd_contrasting

#from cluster.gtcd_contrasting import GLROContrast
#from cluster.gtcd_contrasting import GTLDContrast

# %%
data_eth80_dirname = '/home/hariyuki/data/eth80/'
data_smni_dirname = '/home/hariyuki/data/eeg_smni/'

# %%
# load ETH80
data_eth80_path = os.path.join(data_eth80_dirname, 'eth80-cropped-close128')

image_shape = 32
Nclasses, Nobjects = 8, 10
Npixels = int(round(image_shape**2))

data, labels, classes = eth80.eth80_dataset(data_eth80_path, image_shape)
classes_reverse_dict = dict((y, x) for x, y in classes.items())
Nsamples, Nangles, _, _, Ncolors = data.shape
data = numpy_tools.reshape_np(data, [Nangles, -1, Ncolors], order='F', use_batch=True)
permutation = [0, 2, 1, 3]
data = np.transpose(data, permutation)

n = [Npixels, Nangles, Ncolors]

eth80_dataset = {
    'data': data,
    'n': n,
    'labels': labels,
    'classes': classes,
    'classes_reverse_dict': classes_reverse_dict
}

# %%
# load SMNI EEG
data_smni_path = os.path.join(data_smni_dirname, 'smni_eeg_processed.npz')
df = np.load(data_smni_path)
data, labels = df['data'], df['labels']

Nsubjects, Nchannels, Ntime, Nconditions = data.shape
permutation = [0, 2, 1, 3]
data = np.transpose(data, permutation)
n = [Ntime, Nchannels, Nconditions]

smni_dataset = {
    'data': data,
    'n': n,
    'labels': labels
}

# %%
datasets = {
    'eth80': eth80_dataset,
    'smni': smni_dataset
}
dataset_names = list(datasets.keys())

# %% [markdown]
# ## GLRO contrasting

# %%
commonRanks = 1+np.arange(5)
individualRanks = 1+np.arange(5)

# %%
save_results_dirname = '../results/clustering/'
os.makedirs(save_results_dirname, exist_ok=True)

#save_results_filename_ac = 'gica_contrasted_ac'
#save_results_filename_kg = 'gica_contrasted_kg'

Ntrials = 20
Ntrials_glro = 10
np_random_seed = 720

np_random_state_glro = 800
np.random.seed(np_random_state_glro)
random_states_glro = np.random.randint(1, 1000, Ntrials_glro)
   
def preprocess_glro(dataset, **kwargs):
    assert 'commonRank' in kwargs
    commonRank = kwargs['commonRank']
    assert 'individualRank' in kwargs
    individualRank = kwargs['individualRank']
    assert 'random_state' in kwargs
    random_state = kwargs['random_state']
    if 'sscal' in kwargs:
        sscal = kwargs['sscal']
    else:
        sscal = False
    n = dataset['n']
    contrasting = cluster.gtcd_contrasting.GLROContrast(
        individualRank=individualRank,
        commonRank=commonRank,
        shapeObject=n,
        sourceModes=[0],
        method='als',
        nShortModes=None,
        constraintMethod='projected',
        fullModesConstraint=None,
        maxitnum=10,
        epsilon=1e-5,
        random_state=random_state
    )
    T = contrasting.fit_transform(dataset['data'].copy())
    if sscal:
        T = T - np.mean(T, axis=1, keepdims=True)
        T /= np.std(T, axis=1, keepdims=True, ddof=1)
    return T, dataset['labels']

result_ac, result_kg = [], []
affinity_names_old, linkage_old, dataset_names_old, n_clusters_old = None, None, None, None
for k_comr in range(len(commonRanks)):
    commonRank = commonRanks[k_comr]
    result_ac_crank, result_kg_crank = [], []
    for k_indr in range(len(individualRanks)):
        individualRank = individualRanks[k_indr]
        print(f'\t GLRO: crank={commonRank}, irank={individualRank}')
        result_ac_crank_irank, result_kg_crank_irank = [], []
        for k_trial in range(Ntrials_glro):
            preprocess = {
                'eth80': lambda x: preprocess_glro(
                    x,
                    commonRank=commonRank,
                    individualRank=individualRank,
                    random_state=random_states_glro[k_trial]
                ),
                'smni': lambda x: preprocess_glro(
                    x,
                    commonRank=commonRank,
                    individualRank=individualRank,
                    random_state=random_states_glro[k_trial],
                    sscal=False
                )
            }
            result, affinity_names, linkage, dataset_names, n_clusters, df = hac_clustering_experiment(
                datasets,
                save_results_path=None,#save_results_path,
                preprocess=preprocess,
                verbose=True,
                return_datasets=True
            )
            if not ((k_comr == 0) and (k_indr == 0)):
                assert np.all([dataset_names[l] == dataset_names_old[l] for l in range(len(datasets))])
            dataset_names_old = dataset_names
            #result = np.empty([3, 4, 5])
            result_ac_crank_irank.append(result)

            result, dataset_names, random_states, clust_alg_names, n_clusters = (
                kmeans_gmm_clustering_experiment(
                    df,#datasets,
                    save_results_path=None,#save_results_path,
                    preprocess=None,#preprocess,
                    Ntrials=Ntrials,
                    np_random_seed=np_random_seed,
                    verbose=True
                )
            )
            assert dataset_names == dataset_names_old
            if not ((k_comr == 0) and (k_indr == 0)):
                assert np.all([random_states_old[l] == random_states[l] for l in range(Ntrials)])
            random_states_old = random_states
            #result = np.empty([8, 5])
            result_kg_crank_irank.append(result)
            
            np.savez_compressed(
                'glro_contrasted_clustering_temporal',
                result_ac=result_ac,
                result_kg=result_kg,
                result_ac_crank=result_ac_crank,
                result_kg_crank=result_kg_crank,
                result_ac_crank_irank=result_ac_crank_irank,
                result_kg_crank_irank=result_kg_crank_irank,
            )
            
            
        result_ac_crank.append(result_ac_crank_irank)
        result_kg_crank.append(result_kg_crank_irank)
    result_ac.append(result_ac_crank)
    result_kg.append(result_kg_crank)
result_ac, result_kg = np.array(result_ac), np.array(result_kg)
np.savez_compressed(
    'glro_contrasted_clustering',
    result_ac=result_ac,
    result_kg=result_kg,
    random_states=random_states,
    clust_alg_names=clust_alg_names,
    Ntrials=Ntrials,
    np_random_seed=np_random_seed,
    affinity_names=affinity_names,
    linkage=linkage,
    dataset_names=dataset_names,
    random_states_glro=random_states_glro,
    np_random_state_glro=np_random_state_glro
)
# Out:
# 	 GLRO: crank=1, irank=1
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.431 AMI=0.595 FMI=0.513
# 	 Linkage: average
# ARI=0.356 AMI=0.591 FMI=0.484
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.354 AMI=0.598 FMI=0.479
# 	 Linkage: average
# ARI=0.373 AMI=0.607 FMI=0.499
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.401 AMI=0.564 FMI=0.485
# 	 Linkage: average
# ARI=0.399 AMI=0.646 FMI=0.521
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.213 AMI=0.420 FMI=0.366
# 	 Linkage: average
# ARI=0.336 AMI=0.573 FMI=0.468
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.401 AMI=0.564 FMI=0.485
# 	 Linkage: average
# ARI=0.399 AMI=0.646 FMI=0.521
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.354 AMI=0.598 FMI=0.479
# 	 Linkage: average
# ARI=0.373 AMI=0.607 FMI=0.499
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.029 AMI=0.015 FMI=0.576
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.017 AMI=-0.002 FMI=0.546
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.398/0.421/0.421/0.453
# AMI=0.559/0.573/0.572/0.592
# FMI=0.476/0.499/0.498/0.524
# 	 GMM min/mean/median/max
# ARI=0.321/0.411/0.421/0.461
# AMI=0.487/0.564/0.572/0.597
# FMI=0.416/0.490/0.498/0.529
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.009/0.009/0.013
# AMI=-0.014/-0.002/-0.002/0.009
# FMI=0.720/0.725/0.725/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.289 AMI=0.468 FMI=0.389
# 	 Linkage: average
# ARI=0.297 AMI=0.561 FMI=0.472
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.254 AMI=0.460 FMI=0.395
# 	 Linkage: average
# ARI=0.297 AMI=0.556 FMI=0.472
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.272 AMI=0.543 FMI=0.447
# 	 Linkage: average
# ARI=0.297 AMI=0.556 FMI=0.472
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.239 AMI=0.477 FMI=0.407
# 	 Linkage: average
# ARI=0.280 AMI=0.537 FMI=0.447
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.272 AMI=0.543 FMI=0.447
# 	 Linkage: average
# ARI=0.297 AMI=0.556 FMI=0.472
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.254 AMI=0.460 FMI=0.395
# 	 Linkage: average
# ARI=0.297 AMI=0.556 FMI=0.472
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.010 AMI=-0.004 FMI=0.518
# 	 Linkage: average
# ARI=-0.030 AMI=0.035 FMI=0.691
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.003 AMI=0.010 FMI=0.520
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.018 AMI=0.016 FMI=0.524
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.319/0.341/0.341/0.381
# AMI=0.475/0.497/0.497/0.536
# FMI=0.418/0.436/0.435/0.462
# 	 GMM min/mean/median/max
# ARI=0.295/0.339/0.338/0.393
# AMI=0.446/0.503/0.500/0.556
# FMI=0.402/0.436/0.439/0.478
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.020/0.020/0.027
# AMI=0.002/0.006/0.006/0.009
# FMI=0.698/0.714/0.714/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.303 AMI=0.521 FMI=0.416
# 	 Linkage: average
# ARI=0.431 AMI=0.631 FMI=0.524
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.456 AMI=0.595 FMI=0.528
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.393 AMI=0.640 FMI=0.514
# 	 Linkage: average
# ARI=0.389 AMI=0.644 FMI=0.512
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.420 AMI=0.556 FMI=0.494
# 	 Linkage: average
# ARI=0.435 AMI=0.631 FMI=0.526
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.436 AMI=0.653 FMI=0.533
# 	 Linkage: average
# ARI=0.393 AMI=0.640 FMI=0.514
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.456 AMI=0.595 FMI=0.528
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.026 AMI=0.001 FMI=0.591
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.012 AMI=-0.006 FMI=0.654
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.012 AMI=-0.007 FMI=0.596
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.363/0.433/0.437/0.474
# AMI=0.542/0.576/0.575/0.618
# FMI=0.465/0.508/0.509/0.544
# 	 GMM min/mean/median/max
# ARI=0.336/0.400/0.409/0.469
# AMI=0.516/0.569/0.555/0.643
# FMI=0.440/0.487/0.485/0.548
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.015/0.013/0.053
# AMI=0.009/0.010/0.009/0.025
# FMI=0.696/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.039/0.059/0.059
# AMI=-0.014/0.028/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.298 AMI=0.481 FMI=0.398
# 	 Linkage: average
# ARI=0.260 AMI=0.441 FMI=0.368
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.291 AMI=0.467 FMI=0.390
# 	 Linkage: average
# ARI=0.290 AMI=0.463 FMI=0.388
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.304 AMI=0.529 FMI=0.439
# 	 Linkage: average
# ARI=0.304 AMI=0.587 FMI=0.469
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.286 AMI=0.483 FMI=0.391
# 	 Linkage: average
# ARI=0.270 AMI=0.499 FMI=0.407
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.304 AMI=0.529 FMI=0.439
# 	 Linkage: average
# ARI=0.304 AMI=0.587 FMI=0.469
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.291 AMI=0.467 FMI=0.390
# 	 Linkage: average
# ARI=0.290 AMI=0.463 FMI=0.388
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.021 AMI=0.000 FMI=0.688
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.020 AMI=0.016 FMI=0.552
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.027 AMI=0.002 FMI=0.609
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.214/0.309/0.314/0.382
# AMI=0.381/0.470/0.476/0.517
# FMI=0.314/0.402/0.410/0.457
# 	 GMM min/mean/median/max
# ARI=0.205/0.303/0.306/0.357
# AMI=0.371/0.456/0.469/0.523
# FMI=0.306/0.395/0.400/0.445
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.008/0.005/0.013
# AMI=-0.014/-0.003/-0.014/0.009
# FMI=0.720/0.724/0.720/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.448 AMI=0.596 FMI=0.519
# 	 Linkage: average
# ARI=0.432 AMI=0.651 FMI=0.533
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.450 AMI=0.605 FMI=0.521
# 	 Linkage: average
# ARI=0.427 AMI=0.648 FMI=0.527
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.423 AMI=0.550 FMI=0.501
# 	 Linkage: average
# ARI=0.344 AMI=0.504 FMI=0.460
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.355 AMI=0.504 FMI=0.464
# 	 Linkage: average
# ARI=0.335 AMI=0.477 FMI=0.453
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.423 AMI=0.550 FMI=0.501
# 	 Linkage: average
# ARI=0.344 AMI=0.504 FMI=0.460
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.450 AMI=0.605 FMI=0.521
# 	 Linkage: average
# ARI=0.427 AMI=0.648 FMI=0.527
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.051 AMI=0.014 FMI=0.605
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.022 AMI=-0.003 FMI=0.606
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.038 AMI=0.007 FMI=0.669
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.424/0.439/0.444/0.448
# AMI=0.568/0.590/0.596/0.599
# FMI=0.497/0.511/0.514/0.519
# 	 GMM min/mean/median/max
# ARI=0.345/0.437/0.441/0.522
# AMI=0.526/0.595/0.596/0.640
# FMI=0.448/0.511/0.511/0.578
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.043
# AMI=0.009/0.009/0.009/0.013
# FMI=0.687/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.007/0.005/0.013
# AMI=-0.014/-0.008/-0.014/0.009
# FMI=0.720/0.723/0.720/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.210 AMI=0.398 FMI=0.344
# 	 Linkage: average
# ARI=0.244 AMI=0.430 FMI=0.367
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.224 AMI=0.410 FMI=0.353
# 	 Linkage: average
# ARI=0.280 AMI=0.495 FMI=0.415
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.296 AMI=0.527 FMI=0.430
# 	 Linkage: average
# ARI=0.288 AMI=0.575 FMI=0.458
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.319 AMI=0.489 FMI=0.416
# 	 Linkage: average
# ARI=0.301 AMI=0.540 FMI=0.440
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.296 AMI=0.527 FMI=0.430
# 	 Linkage: average
# ARI=0.288 AMI=0.575 FMI=0.458
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.224 AMI=0.410 FMI=0.353
# 	 Linkage: average
# ARI=0.280 AMI=0.495 FMI=0.415
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.026 AMI=0.002 FMI=0.663
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.008 AMI=-0.007 FMI=0.568
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.016 AMI=-0.006 FMI=0.590
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.302/0.332/0.333/0.364
# AMI=0.458/0.496/0.501/0.522
# FMI=0.400/0.424/0.429/0.445
# 	 GMM min/mean/median/max
# ARI=0.193/0.288/0.308/0.359
# AMI=0.358/0.449/0.471/0.528
# FMI=0.298/0.381/0.403/0.445
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.015/0.013/0.053
# AMI=0.009/0.010/0.009/0.025
# FMI=0.696/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.036/0.059/0.059
# AMI=-0.014/0.025/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.329 AMI=0.587 FMI=0.465
# 	 Linkage: average
# ARI=0.352 AMI=0.597 FMI=0.489
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.319 AMI=0.567 FMI=0.456
# 	 Linkage: average
# ARI=0.320 AMI=0.561 FMI=0.467
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.404 AMI=0.569 FMI=0.485
# 	 Linkage: average
# ARI=0.377 AMI=0.555 FMI=0.475
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.301 AMI=0.469 FMI=0.398
# 	 Linkage: average
# ARI=0.268 AMI=0.506 FMI=0.415
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.398 AMI=0.567 FMI=0.479
# 	 Linkage: average
# ARI=0.377 AMI=0.555 FMI=0.475
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.319 AMI=0.567 FMI=0.456
# 	 Linkage: average
# ARI=0.320 AMI=0.561 FMI=0.467
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.088 AMI=0.038 FMI=0.603
# 	 Linkage: average
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.025 AMI=-0.000 FMI=0.615
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.324/0.392/0.405/0.417
# AMI=0.486/0.552/0.568/0.576
# FMI=0.415/0.475/0.485/0.497
# 	 GMM min/mean/median/max
# ARI=0.289/0.382/0.396/0.486
# AMI=0.468/0.552/0.565/0.617
# FMI=0.390/0.469/0.478/0.551
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.015/0.015/0.018
# AMI=-0.001/0.004/0.004/0.009
# FMI=0.719/0.724/0.724/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.414 AMI=0.553 FMI=0.488
# 	 Linkage: average
# ARI=0.340 AMI=0.561 FMI=0.449
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.388 AMI=0.562 FMI=0.476
# 	 Linkage: average
# ARI=0.356 AMI=0.591 FMI=0.484
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.349 AMI=0.579 FMI=0.464
# 	 Linkage: average
# ARI=0.305 AMI=0.563 FMI=0.454
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.322 AMI=0.506 FMI=0.418
# 	 Linkage: average
# ARI=0.334 AMI=0.558 FMI=0.443
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.349 AMI=0.579 FMI=0.464
# 	 Linkage: average
# ARI=0.305 AMI=0.563 FMI=0.454
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.388 AMI=0.562 FMI=0.476
# 	 Linkage: average
# ARI=0.356 AMI=0.591 FMI=0.484
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.006 FMI=0.511
# 	 Linkage: average
# ARI=-0.035 AMI=0.044 FMI=0.683
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.008 AMI=-0.004 FMI=0.513
# 	 Linkage: average
# ARI=-0.020 AMI=0.016 FMI=0.706
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.004 AMI=-0.003 FMI=0.513
# 	 Linkage: average
# ARI=-0.004 AMI=-0.003 FMI=0.513
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.311/0.402/0.408/0.437
# AMI=0.486/0.551/0.551/0.580
# FMI=0.404/0.482/0.487/0.513
# 	 GMM min/mean/median/max
# ARI=0.353/0.427/0.434/0.490
# AMI=0.483/0.570/0.579/0.618
# FMI=0.433/0.502/0.510/0.552
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.028/0.033/0.039
# AMI=-0.001/0.009/0.011/0.013
# FMI=0.697/0.709/0.698/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.386 AMI=0.616 FMI=0.501
# 	 Linkage: average
# ARI=0.406 AMI=0.715 FMI=0.560
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.426 AMI=0.659 FMI=0.537
# 	 Linkage: average
# ARI=0.426 AMI=0.659 FMI=0.537
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.386 AMI=0.559 FMI=0.477
# 	 Linkage: average
# ARI=0.410 AMI=0.664 FMI=0.529
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.469 AMI=0.618 FMI=0.539
# 	 Linkage: average
# ARI=0.424 AMI=0.635 FMI=0.522
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.401 AMI=0.586 FMI=0.498
# 	 Linkage: average
# ARI=0.351 AMI=0.594 FMI=0.483
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.426 AMI=0.659 FMI=0.537
# 	 Linkage: average
# ARI=0.426 AMI=0.659 FMI=0.537
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.026 AMI=-0.000 FMI=0.644
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.000 AMI=-0.007 FMI=0.579
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.068 AMI=0.039 FMI=0.554
# 	 Linkage: average
# ARI=0.007 AMI=-0.009 FMI=0.691
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.377/0.453/0.456/0.493
# AMI=0.568/0.595/0.596/0.636
# FMI=0.469/0.526/0.530/0.563
# 	 GMM min/mean/median/max
# ARI=0.370/0.423/0.418/0.472
# AMI=0.519/0.586/0.581/0.689
# FMI=0.470/0.506/0.501/0.559
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.015/0.013/0.053
# AMI=0.009/0.010/0.009/0.025
# FMI=0.696/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.045/0.059/0.059
# AMI=0.009/0.036/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.396 AMI=0.584 FMI=0.488
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.375 AMI=0.574 FMI=0.468
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.441 AMI=0.639 FMI=0.526
# 	 Linkage: average
# ARI=0.345 AMI=0.638 FMI=0.500
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.439 AMI=0.626 FMI=0.526
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.371 AMI=0.678 FMI=0.525
# 	 Linkage: average
# ARI=0.341 AMI=0.636 FMI=0.496
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.375 AMI=0.574 FMI=0.468
# 	 Linkage: average
# ARI=0.414 AMI=0.703 FMI=0.555
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.018 AMI=-0.000 FMI=0.565
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.021 AMI=-0.002 FMI=0.670
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.050 AMI=0.027 FMI=0.545
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.380/0.386/0.383/0.426
# AMI=0.590/0.593/0.591/0.628
# FMI=0.474/0.479/0.477/0.516
# 	 GMM min/mean/median/max
# ARI=0.372/0.427/0.423/0.499
# AMI=0.579/0.613/0.610/0.663
# FMI=0.470/0.514/0.513/0.568
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.027/0.033/0.039
# AMI=0.002/0.011/0.011/0.013
# FMI=0.697/0.712/0.698/0.729
# 	 GLRO: crank=1, irank=2
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.380 AMI=0.673 FMI=0.537
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.386 AMI=0.665 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.343 AMI=0.611 FMI=0.497
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.415 AMI=0.634 FMI=0.519
# 	 Linkage: average
# ARI=0.432 AMI=0.651 FMI=0.533
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.343 AMI=0.611 FMI=0.497
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.386 AMI=0.665 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.012 AMI=-0.006 FMI=0.654
# 	 Linkage: average
# ARI=0.019 AMI=-0.003 FMI=0.637
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.042 AMI=0.058 FMI=0.542
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.035 AMI=0.023 FMI=0.596
# 	 Linkage: average
# ARI=-0.026 AMI=0.026 FMI=0.698
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.383/0.441/0.436/0.500
# AMI=0.540/0.585/0.579/0.633
# FMI=0.464/0.513/0.507/0.564
# 	 GMM min/mean/median/max
# ARI=0.348/0.433/0.434/0.504
# AMI=0.522/0.583/0.576/0.666
# FMI=0.444/0.509/0.508/0.564
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.018/0.018/0.018/0.018
# AMI=0.011/0.011/0.011/0.011
# FMI=0.524/0.524/0.524/0.524
# 	 GMM min/mean/median/max
# ARI=0.013/0.030/0.023/0.043
# AMI=-0.002/0.029/0.029/0.047
# FMI=0.529/0.581/0.538/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.393 AMI=0.577 FMI=0.488
# 	 Linkage: average
# ARI=0.438 AMI=0.637 FMI=0.531
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.448 AMI=0.641 FMI=0.538
# 	 Linkage: average
# ARI=0.416 AMI=0.702 FMI=0.559
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.350 AMI=0.587 FMI=0.476
# 	 Linkage: average
# ARI=0.323 AMI=0.591 FMI=0.489
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.362 AMI=0.520 FMI=0.458
# 	 Linkage: average
# ARI=0.360 AMI=0.623 FMI=0.507
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.375 AMI=0.571 FMI=0.472
# 	 Linkage: average
# ARI=0.357 AMI=0.623 FMI=0.509
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.448 AMI=0.641 FMI=0.538
# 	 Linkage: average
# ARI=0.416 AMI=0.702 FMI=0.559
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.032 AMI=0.010 FMI=0.547
# 	 Linkage: average
# ARI=0.074 AMI=0.035 FMI=0.677
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.025 AMI=0.038 FMI=0.569
# 	 Linkage: average
# ARI=-0.007 AMI=-0.005 FMI=0.723
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.096 AMI=0.064 FMI=0.696
# 	 Linkage: average
# ARI=0.030 AMI=0.002 FMI=0.661
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.338/0.406/0.404/0.474
# AMI=0.532/0.562/0.555/0.640
# FMI=0.445/0.483/0.479/0.540
# 	 GMM min/mean/median/max
# ARI=0.303/0.417/0.417/0.481
# AMI=0.524/0.569/0.570/0.617
# FMI=0.415/0.497/0.490/0.548
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.015/0.015/0.018
# AMI=-0.001/0.004/0.004/0.009
# FMI=0.719/0.724/0.724/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.468 AMI=0.605 FMI=0.540
# 	 Linkage: average
# ARI=0.461 AMI=0.651 FMI=0.550
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.415 AMI=0.629 FMI=0.516
# 	 Linkage: average
# ARI=0.461 AMI=0.651 FMI=0.550
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.398 AMI=0.640 FMI=0.516
# 	 Linkage: average
# ARI=0.359 AMI=0.613 FMI=0.496
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.348 AMI=0.558 FMI=0.457
# 	 Linkage: average
# ARI=0.375 AMI=0.609 FMI=0.500
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.398 AMI=0.640 FMI=0.516
# 	 Linkage: average
# ARI=0.353 AMI=0.609 FMI=0.490
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.415 AMI=0.629 FMI=0.516
# 	 Linkage: average
# ARI=0.461 AMI=0.651 FMI=0.550
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.021 AMI=-0.001 FMI=0.605
# 	 Linkage: average
# ARI=-0.009 AMI=-0.011 FMI=0.704
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.034 AMI=0.028 FMI=0.592
# 	 Linkage: average
# ARI=-0.008 AMI=-0.009 FMI=0.658
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.037 AMI=0.005 FMI=0.644
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.385/0.464/0.460/0.532
# AMI=0.570/0.614/0.611/0.651
# FMI=0.475/0.537/0.532/0.591
# 	 GMM min/mean/median/max
# ARI=0.354/0.444/0.452/0.496
# AMI=0.553/0.599/0.599/0.658
# FMI=0.450/0.521/0.527/0.563
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.016/0.013/0.045
# AMI=0.009/0.010/0.009/0.031
# FMI=0.697/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.039/0.045/0.059
# AMI=0.009/0.030/0.031/0.048
# FMI=0.715/0.720/0.716/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.416 AMI=0.620 FMI=0.510
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.431 AMI=0.623 FMI=0.518
# 	 Linkage: average
# ARI=0.389 AMI=0.679 FMI=0.540
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.401 AMI=0.602 FMI=0.490
# 	 Linkage: average
# ARI=0.380 AMI=0.669 FMI=0.529
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.295 AMI=0.508 FMI=0.408
# 	 Linkage: average
# ARI=0.358 AMI=0.660 FMI=0.514
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.401 AMI=0.602 FMI=0.490
# 	 Linkage: average
# ARI=0.388 AMI=0.582 FMI=0.487
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.431 AMI=0.623 FMI=0.518
# 	 Linkage: average
# ARI=0.389 AMI=0.679 FMI=0.540
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.003 AMI=-0.008 FMI=0.630
# 	 Linkage: average
# ARI=0.015 AMI=-0.003 FMI=0.598
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.024 AMI=0.004 FMI=0.565
# 	 Linkage: average
# ARI=0.007 AMI=-0.009 FMI=0.691
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.066 AMI=0.033 FMI=0.559
# 	 Linkage: average
# ARI=-0.019 AMI=-0.000 FMI=0.552
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.365/0.413/0.424/0.445
# AMI=0.573/0.602/0.612/0.632
# FMI=0.464/0.500/0.508/0.530
# 	 GMM min/mean/median/max
# ARI=0.351/0.433/0.433/0.503
# AMI=0.539/0.600/0.602/0.656
# FMI=0.442/0.512/0.510/0.568
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.015/0.013/0.045
# AMI=-0.001/0.010/0.009/0.031
# FMI=0.716/0.728/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.045/0.059/0.059
# AMI=0.009/0.036/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.416 AMI=0.660 FMI=0.537
# 	 Linkage: average
# ARI=0.390 AMI=0.688 FMI=0.546
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.446 AMI=0.641 FMI=0.537
# 	 Linkage: average
# ARI=0.390 AMI=0.688 FMI=0.546
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.373 AMI=0.572 FMI=0.472
# 	 Linkage: average
# ARI=0.358 AMI=0.617 FMI=0.499
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.314 AMI=0.568 FMI=0.462
# 	 Linkage: average
# ARI=0.416 AMI=0.702 FMI=0.559
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.373 AMI=0.572 FMI=0.472
# 	 Linkage: average
# ARI=0.358 AMI=0.617 FMI=0.499
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.446 AMI=0.641 FMI=0.537
# 	 Linkage: average
# ARI=0.390 AMI=0.688 FMI=0.546
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.015 AMI=-0.006 FMI=0.604
# 	 Linkage: average
# ARI=0.018 AMI=-0.001 FMI=0.719
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.018 AMI=0.020 FMI=0.549
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.376/0.421/0.421/0.459
# AMI=0.573/0.616/0.609/0.659
# FMI=0.467/0.509/0.505/0.544
# 	 GMM min/mean/median/max
# ARI=0.343/0.431/0.440/0.504
# AMI=0.508/0.617/0.632/0.658
# FMI=0.428/0.516/0.526/0.574
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.017/0.013/0.063
# AMI=0.009/0.012/0.009/0.040
# FMI=0.705/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.021/0.013/0.045
# AMI=-0.014/0.009/0.009/0.031
# FMI=0.716/0.721/0.720/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.435 AMI=0.635 FMI=0.527
# 	 Linkage: average
# ARI=0.406 AMI=0.684 FMI=0.549
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.403 AMI=0.640 FMI=0.517
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.423 AMI=0.618 FMI=0.511
# 	 Linkage: average
# ARI=0.398 AMI=0.674 FMI=0.543
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.403 AMI=0.618 FMI=0.507
# 	 Linkage: average
# ARI=0.347 AMI=0.619 FMI=0.506
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.423 AMI=0.618 FMI=0.511
# 	 Linkage: average
# ARI=0.398 AMI=0.674 FMI=0.543
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.403 AMI=0.640 FMI=0.517
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.014 AMI=0.012 FMI=0.538
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.014 AMI=-0.005 FMI=0.544
# 	 Linkage: average
# ARI=0.077 AMI=0.055 FMI=0.705
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.008 FMI=0.617
# 	 Linkage: average
# ARI=-0.016 AMI=-0.005 FMI=0.577
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.393/0.425/0.421/0.490
# AMI=0.559/0.602/0.610/0.637
# FMI=0.476/0.507/0.503/0.558
# 	 GMM min/mean/median/max
# ARI=0.354/0.430/0.435/0.493
# AMI=0.552/0.589/0.592/0.640
# FMI=0.449/0.508/0.515/0.557
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.031
# AMI=-0.001/0.008/0.009/0.009
# FMI=0.688/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.026/0.031/0.031
# AMI=-0.001/0.011/0.015/0.015
# FMI=0.717/0.719/0.717/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.396 AMI=0.624 FMI=0.500
# 	 Linkage: average
# ARI=0.389 AMI=0.688 FMI=0.545
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.416 AMI=0.610 FMI=0.504
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.423 AMI=0.660 FMI=0.528
# 	 Linkage: average
# ARI=0.364 AMI=0.625 FMI=0.510
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.371 AMI=0.573 FMI=0.472
# 	 Linkage: average
# ARI=0.357 AMI=0.643 FMI=0.516
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.405 AMI=0.636 FMI=0.512
# 	 Linkage: average
# ARI=0.367 AMI=0.570 FMI=0.471
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.416 AMI=0.610 FMI=0.504
# 	 Linkage: average
# ARI=0.410 AMI=0.696 FMI=0.553
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.014 AMI=0.053 FMI=0.562
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.026 AMI=0.001 FMI=0.646
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.402/0.434/0.429/0.495
# AMI=0.545/0.594/0.598/0.637
# FMI=0.474/0.510/0.511/0.562
# 	 GMM min/mean/median/max
# ARI=0.359/0.437/0.446/0.495
# AMI=0.503/0.587/0.590/0.663
# FMI=0.447/0.512/0.517/0.564
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.016/0.013/0.045
# AMI=0.009/0.011/0.009/0.031
# FMI=0.716/0.728/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.032/0.045/0.045
# AMI=-0.001/0.021/0.031/0.031
# FMI=0.716/0.720/0.716/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.396 AMI=0.550 FMI=0.478
# 	 Linkage: average
# ARI=0.413 AMI=0.649 FMI=0.526
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.383 AMI=0.615 FMI=0.499
# 	 Linkage: average
# ARI=0.403 AMI=0.670 FMI=0.536
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.418 AMI=0.623 FMI=0.514
# 	 Linkage: average
# ARI=0.374 AMI=0.641 FMI=0.527
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.316 AMI=0.532 FMI=0.445
# 	 Linkage: average
# ARI=0.329 AMI=0.620 FMI=0.500
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.455 AMI=0.630 FMI=0.538
# 	 Linkage: average
# ARI=0.374 AMI=0.641 FMI=0.527
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.383 AMI=0.615 FMI=0.499
# 	 Linkage: average
# ARI=0.403 AMI=0.670 FMI=0.536
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.007 AMI=-0.002 FMI=0.515
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.040 AMI=0.028 FMI=0.630
# 	 Linkage: average
# ARI=-0.045 AMI=0.057 FMI=0.628
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.037 AMI=0.005 FMI=0.644
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.405/0.461/0.469/0.517
# AMI=0.546/0.603/0.607/0.641
# FMI=0.479/0.532/0.536/0.578
# 	 GMM min/mean/median/max
# ARI=0.371/0.426/0.435/0.480
# AMI=0.519/0.588/0.588/0.636
# FMI=0.453/0.507/0.513/0.550
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.016/0.013/0.045
# AMI=0.009/0.011/0.009/0.031
# FMI=0.716/0.728/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.045/0.059/0.059
# AMI=0.009/0.036/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.434 AMI=0.650 FMI=0.531
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.429 AMI=0.622 FMI=0.516
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.448 AMI=0.652 FMI=0.546
# 	 Linkage: average
# ARI=0.449 AMI=0.630 FMI=0.536
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.432 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.448 AMI=0.652 FMI=0.546
# 	 Linkage: average
# ARI=0.418 AMI=0.601 FMI=0.522
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.429 AMI=0.622 FMI=0.516
# 	 Linkage: average
# ARI=0.391 AMI=0.668 FMI=0.536
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.003 AMI=-0.008 FMI=0.623
# 	 Linkage: average
# ARI=-0.018 AMI=-0.002 FMI=0.556
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.044 AMI=0.045 FMI=0.640
# 	 Linkage: average
# ARI=-0.031 AMI=0.020 FMI=0.583
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.028 AMI=0.005 FMI=0.560
# 	 Linkage: average
# ARI=-0.024 AMI=0.004 FMI=0.565
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.377/0.414/0.407/0.479
# AMI=0.564/0.595/0.606/0.622
# FMI=0.471/0.498/0.496/0.547
# 	 GMM min/mean/median/max
# ARI=0.364/0.403/0.402/0.472
# AMI=0.561/0.586/0.573/0.658
# FMI=0.462/0.493/0.488/0.539
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.031/0.039/0.039
# AMI=0.009/0.012/0.013/0.013
# FMI=0.697/0.707/0.697/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.451 AMI=0.629 FMI=0.537
# 	 Linkage: average
# ARI=0.453 AMI=0.638 FMI=0.540
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.358 AMI=0.556 FMI=0.457
# 	 Linkage: average
# ARI=0.331 AMI=0.617 FMI=0.491
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.461 AMI=0.624 FMI=0.540
# 	 Linkage: average
# ARI=0.453 AMI=0.616 FMI=0.542
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.420 AMI=0.574 FMI=0.502
# 	 Linkage: average
# ARI=0.456 AMI=0.620 FMI=0.544
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.461 AMI=0.624 FMI=0.540
# 	 Linkage: average
# ARI=0.453 AMI=0.616 FMI=0.542
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.358 AMI=0.556 FMI=0.457
# 	 Linkage: average
# ARI=0.331 AMI=0.617 FMI=0.491
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.060 AMI=0.019 FMI=0.613
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.031 AMI=0.073 FMI=0.549
# 	 Linkage: average
# ARI=0.010 AMI=-0.010 FMI=0.710
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.037 AMI=0.005 FMI=0.644
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.348/0.413/0.415/0.453
# AMI=0.523/0.564/0.565/0.587
# FMI=0.449/0.489/0.491/0.522
# 	 GMM min/mean/median/max
# ARI=0.298/0.414/0.423/0.507
# AMI=0.471/0.575/0.576/0.623
# FMI=0.399/0.496/0.507/0.567
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.045
# AMI=0.009/0.010/0.009/0.031
# FMI=0.716/0.728/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.035/0.018/0.059
# AMI=-0.001/0.024/0.009/0.048
# FMI=0.715/0.720/0.719/0.729
# 	 GLRO: crank=1, irank=3
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.422 AMI=0.619 FMI=0.512
# 	 Linkage: average
# ARI=0.329 AMI=0.617 FMI=0.488
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.340 AMI=0.566 FMI=0.459
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.318 AMI=0.470 FMI=0.441
# 	 Linkage: average
# ARI=0.052 AMI=0.184 FMI=0.300
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.405 AMI=0.569 FMI=0.501
# 	 Linkage: average
# ARI=0.223 AMI=0.417 FMI=0.388
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.318 AMI=0.470 FMI=0.441
# 	 Linkage: average
# ARI=0.052 AMI=0.184 FMI=0.300
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.340 AMI=0.566 FMI=0.459
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.004 AMI=-0.006 FMI=0.585
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.011 AMI=-0.006 FMI=0.552
# 	 Linkage: average
# ARI=-0.029 AMI=0.029 FMI=0.576
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.115 AMI=0.058 FMI=0.603
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.356/0.433/0.428/0.514
# AMI=0.550/0.589/0.583/0.654
# FMI=0.454/0.510/0.505/0.576
# 	 GMM min/mean/median/max
# ARI=0.330/0.450/0.445/0.618
# AMI=0.518/0.612/0.619/0.741
# FMI=0.431/0.526/0.527/0.662
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.016/0.018/0.018
# AMI=-0.001/0.002/-0.001/0.009
# FMI=0.719/0.722/0.719/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.405 AMI=0.568 FMI=0.483
# 	 Linkage: average
# ARI=0.391 AMI=0.585 FMI=0.486
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.354 AMI=0.519 FMI=0.441
# 	 Linkage: average
# ARI=0.304 AMI=0.546 FMI=0.441
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.360 AMI=0.614 FMI=0.497
# 	 Linkage: average
# ARI=0.300 AMI=0.569 FMI=0.471
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.395 AMI=0.565 FMI=0.484
# 	 Linkage: average
# ARI=0.324 AMI=0.558 FMI=0.462
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.357 AMI=0.597 FMI=0.489
# 	 Linkage: average
# ARI=0.300 AMI=0.569 FMI=0.471
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.354 AMI=0.519 FMI=0.441
# 	 Linkage: average
# ARI=0.304 AMI=0.546 FMI=0.441
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.041 AMI=0.050 FMI=0.609
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.030 AMI=0.042 FMI=0.580
# 	 Linkage: average
# ARI=-0.037 AMI=0.025 FMI=0.659
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.037 AMI=0.037 FMI=0.600
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.350/0.397/0.400/0.439
# AMI=0.515/0.556/0.558/0.595
# FMI=0.441/0.478/0.482/0.511
# 	 GMM min/mean/median/max
# ARI=0.319/0.410/0.405/0.490
# AMI=0.532/0.567/0.558/0.621
# FMI=0.423/0.489/0.484/0.552
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.016/0.018/0.018
# AMI=-0.001/0.002/-0.001/0.009
# FMI=0.719/0.722/0.719/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.346 AMI=0.642 FMI=0.500
# 	 Linkage: average
# ARI=0.389 AMI=0.683 FMI=0.544
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.374 AMI=0.667 FMI=0.531
# 	 Linkage: average
# ARI=0.389 AMI=0.683 FMI=0.544
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.379 AMI=0.599 FMI=0.490
# 	 Linkage: average
# ARI=0.352 AMI=0.626 FMI=0.505
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.553 AMI=0.775 FMI=0.639
# 	 Linkage: average
# ARI=0.364 AMI=0.659 FMI=0.518
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.379 AMI=0.599 FMI=0.490
# 	 Linkage: average
# ARI=0.352 AMI=0.626 FMI=0.505
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.374 AMI=0.667 FMI=0.531
# 	 Linkage: average
# ARI=0.389 AMI=0.683 FMI=0.544
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.034 AMI=0.014 FMI=0.606
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.022 AMI=0.031 FMI=0.562
# 	 Linkage: average
# ARI=-0.026 AMI=0.026 FMI=0.698
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.079 AMI=0.059 FMI=0.554
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.358/0.426/0.413/0.552
# AMI=0.564/0.633/0.625/0.770
# FMI=0.453/0.520/0.513/0.638
# 	 GMM min/mean/median/max
# ARI=0.343/0.456/0.459/0.591
# AMI=0.586/0.653/0.642/0.807
# FMI=0.486/0.547/0.538/0.677
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.016/0.018/0.018
# AMI=-0.001/0.002/-0.001/0.009
# FMI=0.719/0.722/0.719/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.358 AMI=0.579 FMI=0.469
# 	 Linkage: average
# ARI=0.329 AMI=0.617 FMI=0.488
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.348 AMI=0.545 FMI=0.451
# 	 Linkage: average
# ARI=0.334 AMI=0.612 FMI=0.499
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.375 AMI=0.556 FMI=0.472
# 	 Linkage: average
# ARI=0.346 AMI=0.586 FMI=0.488
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.447 AMI=0.591 FMI=0.521
# 	 Linkage: average
# ARI=0.401 AMI=0.643 FMI=0.525
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.397 AMI=0.566 FMI=0.484
# 	 Linkage: average
# ARI=0.374 AMI=0.627 FMI=0.508
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.348 AMI=0.545 FMI=0.451
# 	 Linkage: average
# ARI=0.334 AMI=0.612 FMI=0.499
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.040 AMI=0.032 FMI=0.652
# 	 Linkage: average
# ARI=0.005 AMI=-0.014 FMI=0.720
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.016 AMI=0.040 FMI=0.557
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.051 AMI=0.014 FMI=0.605
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.337/0.404/0.395/0.519
# AMI=0.529/0.569/0.558/0.652
# FMI=0.438/0.485/0.475/0.580
# 	 GMM min/mean/median/max
# ARI=0.341/0.443/0.433/0.585
# AMI=0.538/0.595/0.585/0.679
# FMI=0.441/0.518/0.512/0.633
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.045/0.059/0.059
# AMI=0.009/0.036/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.441 AMI=0.654 FMI=0.538
# 	 Linkage: average
# ARI=0.404 AMI=0.644 FMI=0.522
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.456 AMI=0.615 FMI=0.538
# 	 Linkage: average
# ARI=0.345 AMI=0.564 FMI=0.481
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.456 AMI=0.605 FMI=0.528
# 	 Linkage: average
# ARI=0.391 AMI=0.615 FMI=0.509
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.456 AMI=0.615 FMI=0.538
# 	 Linkage: average
# ARI=0.345 AMI=0.564 FMI=0.481
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.027 AMI=0.022 FMI=0.568
# 	 Linkage: average
# ARI=0.018 AMI=-0.001 FMI=0.719
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.113 AMI=0.055 FMI=0.608
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.369/0.431/0.432/0.487
# AMI=0.537/0.582/0.586/0.619
# FMI=0.466/0.508/0.510/0.553
# 	 GMM min/mean/median/max
# ARI=0.306/0.428/0.430/0.577
# AMI=0.526/0.599/0.591/0.729
# FMI=0.418/0.510/0.509/0.634
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.044/0.059/0.059
# AMI=0.009/0.035/0.048/0.048
# FMI=0.715/0.719/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.373 AMI=0.576 FMI=0.469
# 	 Linkage: average
# ARI=0.358 AMI=0.565 FMI=0.460
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.317 AMI=0.485 FMI=0.411
# 	 Linkage: average
# ARI=0.360 AMI=0.597 FMI=0.487
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.303 AMI=0.547 FMI=0.440
# 	 Linkage: average
# ARI=0.343 AMI=0.562 FMI=0.464
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.326 AMI=0.491 FMI=0.418
# 	 Linkage: average
# ARI=0.314 AMI=0.562 FMI=0.471
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.328 AMI=0.571 FMI=0.460
# 	 Linkage: average
# ARI=0.309 AMI=0.569 FMI=0.469
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.317 AMI=0.485 FMI=0.411
# 	 Linkage: average
# ARI=0.360 AMI=0.597 FMI=0.487
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.021 AMI=-0.001 FMI=0.563
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.031 AMI=0.013 FMI=0.593
# 	 Linkage: average
# ARI=-0.032 AMI=0.016 FMI=0.588
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.346/0.403/0.407/0.447
# AMI=0.518/0.557/0.561/0.595
# FMI=0.440/0.482/0.485/0.520
# 	 GMM min/mean/median/max
# ARI=0.341/0.408/0.396/0.511
# AMI=0.497/0.568/0.564/0.632
# FMI=0.425/0.487/0.479/0.569
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.016/0.013/0.049
# AMI=0.009/0.011/0.009/0.031
# FMI=0.706/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.038/0.031/0.059
# AMI=0.009/0.028/0.015/0.048
# FMI=0.715/0.720/0.717/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.437 AMI=0.578 FMI=0.513
# 	 Linkage: average
# ARI=0.371 AMI=0.639 FMI=0.520
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.395 AMI=0.680 FMI=0.539
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.399 AMI=0.646 FMI=0.521
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.347 AMI=0.516 FMI=0.444
# 	 Linkage: average
# ARI=0.306 AMI=0.583 FMI=0.476
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.436 AMI=0.651 FMI=0.533
# 	 Linkage: average
# ARI=0.427 AMI=0.648 FMI=0.527
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.395 AMI=0.680 FMI=0.539
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.009 AMI=0.065 FMI=0.552
# 	 Linkage: average
# ARI=-0.041 AMI=0.039 FMI=0.619
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.037 AMI=0.025 FMI=0.659
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.361/0.444/0.450/0.494
# AMI=0.565/0.618/0.624/0.647
# FMI=0.460/0.525/0.529/0.558
# 	 GMM min/mean/median/max
# ARI=0.381/0.460/0.454/0.548
# AMI=0.526/0.612/0.619/0.653
# FMI=0.475/0.534/0.536/0.602
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.017/0.013/0.063
# AMI=0.009/0.012/0.009/0.040
# FMI=0.705/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.005/0.025/0.013/0.045
# AMI=-0.014/0.013/0.009/0.031
# FMI=0.716/0.721/0.720/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.436 AMI=0.659 FMI=0.539
# 	 Linkage: average
# ARI=0.377 AMI=0.672 FMI=0.534
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.436 AMI=0.659 FMI=0.539
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.490 AMI=0.627 FMI=0.555
# 	 Linkage: average
# ARI=0.412 AMI=0.632 FMI=0.529
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.441 AMI=0.607 FMI=0.519
# 	 Linkage: average
# ARI=0.358 AMI=0.576 FMI=0.464
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.490 AMI=0.627 FMI=0.555
# 	 Linkage: average
# ARI=0.412 AMI=0.632 FMI=0.529
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.436 AMI=0.659 FMI=0.539
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.008 AMI=0.001 FMI=0.519
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.030 AMI=0.007 FMI=0.656
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.020 AMI=-0.002 FMI=0.567
# 	 Linkage: average
# ARI=-0.002 AMI=-0.014 FMI=0.712
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.339/0.423/0.424/0.482
# AMI=0.539/0.589/0.582/0.652
# FMI=0.450/0.505/0.506/0.556
# 	 GMM min/mean/median/max
# ARI=0.353/0.420/0.422/0.482
# AMI=0.524/0.586/0.579/0.655
# FMI=0.452/0.504/0.508/0.551
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.015/0.013/0.049
# AMI=0.009/0.010/0.009/0.026
# FMI=0.706/0.728/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.043/0.059/0.059
# AMI=0.009/0.034/0.048/0.048
# FMI=0.715/0.720/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.441 AMI=0.636 FMI=0.531
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.423 AMI=0.617 FMI=0.512
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.435 AMI=0.639 FMI=0.531
# 	 Linkage: average
# ARI=0.413 AMI=0.605 FMI=0.518
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.512 AMI=0.642 FMI=0.577
# 	 Linkage: average
# ARI=0.499 AMI=0.689 FMI=0.583
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.435 AMI=0.639 FMI=0.531
# 	 Linkage: average
# ARI=0.413 AMI=0.605 FMI=0.518
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.423 AMI=0.617 FMI=0.512
# 	 Linkage: average
# ARI=0.374 AMI=0.667 FMI=0.531
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.012 AMI=0.003 FMI=0.525
# 	 Linkage: average
# ARI=-0.042 AMI=0.038 FMI=0.646
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.010 AMI=0.023 FMI=0.540
# 	 Linkage: average
# ARI=-0.030 AMI=0.035 FMI=0.691
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.012 AMI=0.003 FMI=0.525
# 	 Linkage: average
# ARI=-0.045 AMI=0.051 FMI=0.634
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.357/0.433/0.430/0.504
# AMI=0.549/0.600/0.601/0.647
# FMI=0.449/0.514/0.507/0.569
# 	 GMM min/mean/median/max
# ARI=0.336/0.426/0.432/0.556
# AMI=0.538/0.602/0.611/0.674
# FMI=0.440/0.511/0.507/0.609
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.039
# AMI=0.009/0.009/0.009/0.013
# FMI=0.697/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.044/0.059/0.059
# AMI=-0.001/0.033/0.048/0.048
# FMI=0.715/0.718/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.351 AMI=0.524 FMI=0.439
# 	 Linkage: average
# ARI=0.404 AMI=0.598 FMI=0.502
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.357 AMI=0.522 FMI=0.444
# 	 Linkage: average
# ARI=0.390 AMI=0.584 FMI=0.488
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.310 AMI=0.522 FMI=0.430
# 	 Linkage: average
# ARI=0.315 AMI=0.562 FMI=0.459
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.351 AMI=0.571 FMI=0.478
# 	 Linkage: average
# ARI=0.330 AMI=0.574 FMI=0.465
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.305 AMI=0.514 FMI=0.427
# 	 Linkage: average
# ARI=0.315 AMI=0.562 FMI=0.459
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.357 AMI=0.522 FMI=0.444
# 	 Linkage: average
# ARI=0.390 AMI=0.584 FMI=0.488
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.059 AMI=0.048 FMI=0.715
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.024 AMI=0.052 FMI=0.573
# 	 Linkage: average
# ARI=0.010 AMI=-0.010 FMI=0.710
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.006 AMI=-0.001 FMI=0.526
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.341/0.394/0.397/0.434
# AMI=0.505/0.552/0.552/0.585
# FMI=0.429/0.474/0.477/0.510
# 	 GMM min/mean/median/max
# ARI=0.367/0.446/0.433/0.533
# AMI=0.525/0.589/0.579/0.641
# FMI=0.450/0.518/0.506/0.588
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.039/0.038/0.059
# AMI=0.009/0.029/0.023/0.048
# FMI=0.715/0.720/0.716/0.729
# 	 GLRO: crank=1, irank=4
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.372 AMI=0.559 FMI=0.466
# 	 Linkage: average
# ARI=0.446 AMI=0.607 FMI=0.531
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.367 AMI=0.528 FMI=0.460
# 	 Linkage: average
# ARI=0.390 AMI=0.653 FMI=0.527
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.506 AMI=0.707 FMI=0.583
# 	 Linkage: average
# ARI=0.420 AMI=0.643 FMI=0.523
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.401 AMI=0.554 FMI=0.481
# 	 Linkage: average
# ARI=0.411 AMI=0.683 FMI=0.548
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.421 AMI=0.578 FMI=0.503
# 	 Linkage: average
# ARI=0.420 AMI=0.643 FMI=0.523
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.367 AMI=0.528 FMI=0.460
# 	 Linkage: average
# ARI=0.390 AMI=0.653 FMI=0.527
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.008 AMI=-0.003 FMI=0.515
# 	 Linkage: average
# ARI=-0.030 AMI=0.012 FMI=0.673
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.007 AMI=0.015 FMI=0.522
# 	 Linkage: average
# ARI=-0.014 AMI=0.005 FMI=0.714
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=-0.012 AMI=0.002 FMI=0.527
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.350/0.421/0.430/0.494
# AMI=0.517/0.585/0.593/0.627
# FMI=0.446/0.500/0.504/0.559
# 	 GMM min/mean/median/max
# ARI=0.358/0.465/0.467/0.592
# AMI=0.542/0.610/0.607/0.714
# FMI=0.451/0.537/0.540/0.644
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.013/0.013/0.013
# AMI=0.009/0.009/0.009/0.009
# FMI=0.729/0.729/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.017/0.018/0.031
# AMI=-0.001/0.003/-0.001/0.015
# FMI=0.717/0.722/0.719/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.431 AMI=0.588 FMI=0.512
# 	 Linkage: average
# ARI=0.362 AMI=0.633 FMI=0.511
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.488 AMI=0.627 FMI=0.554
# 	 Linkage: average
# ARI=0.422 AMI=0.647 FMI=0.527
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.427 AMI=0.648 FMI=0.527
# 	 Linkage: average
# ARI=0.347 AMI=0.625 FMI=0.507
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.338 AMI=0.511 FMI=0.437
# 	 Linkage: average
# ARI=0.362 AMI=0.633 FMI=0.511
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.399 AMI=0.641 FMI=0.517
# 	 Linkage: average
# ARI=0.356 AMI=0.597 FMI=0.488
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.488 AMI=0.627 FMI=0.554
# 	 Linkage: average
# ARI=0.422 AMI=0.647 FMI=0.527
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.009 AMI=-0.006 FMI=0.520
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.123 AMI=0.085 FMI=0.577
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.000 AMI=-0.002 FMI=0.516
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80
# 	 kmeans min/mean/median/max
# ARI=0.379/0.439/0.443/0.486
# AMI=0.542/0.596/0.608/0.641
# FMI=0.463/0.514/0.521/0.553
# 	 GMM min/mean/median/max
# ARI=0.338/0.462/0.462/0.581
# AMI=0.533/0.615/0.611/0.727
# FMI=0.438/0.533/0.530/0.637
# 			 smni
# 	 kmeans min/mean/median/max
# ARI=0.013/0.014/0.013/0.039
# AMI=0.009/0.009/0.009/0.013
# FMI=0.697/0.727/0.729/0.729
# 	 GMM min/mean/median/max
# ARI=0.013/0.043/0.059/0.059
# AMI=0.009/0.034/0.048/0.048
# FMI=0.715/0.720/0.715/0.729
# 			 eth80
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.389 AMI=0.599 FMI=0.488
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.305 AMI=0.505 FMI=0.419
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=0.447 AMI=0.585 FMI=0.521
# 	 Linkage: average
# ARI=0.464 AMI=0.651 FMI=0.556
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=0.463 AMI=0.621 FMI=0.541
# 	 Linkage: average
# ARI=0.454 AMI=0.646 FMI=0.549
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.447 AMI=0.585 FMI=0.521
# 	 Linkage: average
# ARI=0.464 AMI=0.651 FMI=0.556
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.305 AMI=0.505 FMI=0.419
# 	 Linkage: average
# ARI=0.344 AMI=0.632 FMI=0.511
# 			 smni
# 		 Affinity: l1
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: l2
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: cosine
# 	 Linkage: complete
# ARI=-0.015 AMI=-0.006 FMI=0.696
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: canberra
# 	 Linkage: complete
# ARI=-0.003 AMI=0.054 FMI=0.553
# 	 Linkage: average
# ARI=0.026 AMI=0.032 FMI=0.727
# 		 Affinity: correlation
# 	 Linkage: complete
# ARI=0.060 AMI=0.019 FMI=0.613
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 		 Affinity: rbf
# 	 Linkage: complete
# ARI=0.013 AMI=0.009 FMI=0.729
# 	 Linkage: average
# ARI=0.013 AMI=0.009 FMI=0.729
# 			 eth80

# %%
 smni
	 kmeans min/mean/median/max
ARI=0.013/0.013/0.013/0.013
AMI=0.009/0.009/0.009/0.009
FMI=0.729/0.729/0.729/0.729
	 GMM min/mean/median/max
ARI=0.005/0.009/0.009/0.013
AMI=-0.014/-0.002/-0.002/0.009
FMI=0.720/0.725/0.725/0.729

# %%
dataset_num = 0

for k in range(3):
    print(
        f'{np.min(result_ac, axis=2)[:, :, dataset_num, :, :, k].max():.3f}/'
        f'{np.mean(result_ac, axis=2)[:, :, dataset_num, :, :, k].max():.3f}/'
        f'{np.median(result_ac, axis=2)[:, :, dataset_num, :, :, k].max():.3f}/'
        f'{np.max(result_ac, axis=2)[:, :, dataset_num, :, :, k].max():.3f}\t\t'
        f'{np.min(result_kg.mean(axis=-2), axis=2)[:, :, dataset_num, :, k].max():.3f}/'
        f'{np.mean(result_kg.mean(axis=-2), axis=2)[:, :, dataset_num, :, k].max():.3f}/'
        f'{np.median(result_kg.mean(axis=-2), axis=2)[:, :, dataset_num, :, k].max():.3f}/'
        f'{np.max(result_kg.mean(axis=-2), axis=2)[:, :, dataset_num, :, k].max():.3f}\t\t'
    )
# Out:
# 0.407/0.472/0.520/0.687		0.442/0.473/0.482/0.519
# 0.637/0.693/0.730/0.810		0.628/0.662/0.657/0.712
# 0.526/0.580/0.609/0.731		0.530/0.554/0.561/0.597

# %%
from td.utils import reshape, prodTenMat

import group_tcd
#import gtcd_jit as gtcd
import gtcd

maxitnum = 100
epsilon = 1e-8
verbose = True

_maxInnerIt = 15
_tolRes = 1e-8
_tolGrad = 1e-8
_tolSwamp = 1e-8

def alsM(a, x0, cdN, ldN, tdN, maxitnum, constraints, verbose):
    return gtcd.tcd(
        a, x0=x0, canonical_dict=cdN, lro_dict=ldN, tucker_dict=tdN, maxitnum=maxitnum, 
        tolRes=_tolRes, tolGrad=_tolGrad, tolSwamp=_tolSwamp, method='als', verbose=verbose, 
        regTGD=None, regPGD=None, doSA=0, constraints=constraints
    )

def doglegM(a, x0, cdN, ldN, tdN, maxitnum, constraints, verbose):
    return gtcd.tcd(
        a, x0=x0, canonical_dict=cdN, lro_dict=ldN, tucker_dict=tdN, maxitnum=maxitnum, 
        maxInnerIt=_maxInnerIt, tolRes=_tolRes, tolGrad=_tolGrad, tolSwamp=_tolSwamp, method='tr', 
        verbose=verbose, doSA=0, constraints=constraints, trStep='dogleg',
        trDelta0=1.2,trEta=0.23
    )
        
groupConstraintMethod = 'projected'


source_mode = [1]
nShortModes = 1
fullModesConstraint = None

individualRank = 3
commonRank = 4
random_state = 576

shape = [-1] + list(n)
T = reshape(data, shape)
transposition = list(range(1, len(n)+1)) + [0]
T = np.transpose(T, transposition)
T = T.astype(np.float32)
n = T.shape
groupConstraint = group_tcd.group_constraint(
    n, source_mode, groupConstraintMethod
)
normT = np.linalg.norm(T)
T /= normT
cdN = None
P = len(T.shape)-nShortModes
ldN = {
    'L': [individualRank]*n[-1] + [commonRank],
    'P': P,
    'fullModesConstraint': fullModesConstraint
}
tdN = None
x0 = None
np.random.seed(random_state)
#tic = time.clock()
cdN, ldN, tdN, info = doglegM(#alsM(
    T, x0, cdN, ldN, tdN, maxitnum, groupConstraint, verbose
)
#toc = time.clock()
#self.timesEstimate = toc-tic
indCommon = commonRank
fmc = fullModesConstraint
contrasted = [None]*len(n)
group_part = copy.deepcopy(ldn)
for k in range(len(n)):
    if k < P:
        if (fmc is not None) and (fmc[k] is not None):
            contrasted[k] = ldN['B'][k][2][:, -indCommon:].copy()
            if ldN['B'][k][2].shape[1] == indCommon:
                ldN['B'][k][2] = None
            else:
                ldN['B'][k][2] = ldN['B'][k][2][:, :-indCommon].copy()
        else:
            contrasted[k] = ldN['B'][k][:, -indCommon:].copy()
            ldN['B'][k] = ldN['B'][k][:, :-indCommon].copy()
            group_part['B'][k] = group_part['B'][k][:, -indCommon]
    else:
        contrasted[k] = ldN['B'][k][:, -1:].copy()
        ldN['B'][k] = ldN['B'][k][:, :-1].copy()
        group_part['B'][k] = group_part['B'][k][:, -1:]
ldN['L'] = ldN['L'][:-1]
group_part['L'] = group_part['L'][-1:]
del ldN['E'], group_part['E']
contrastedT = gtcd.recover(n, lro_dict=ldN)
permutation = np.roll(np.arange(contrastedT.ndim), 1)
contrastedT = np.transpose(contrastedT, permutation)
groupT = gtcd.recover(n, lro_dict=group_part)
groupT = np.transpose(groupT, permutation)

np.savez_compressed(
    'example_glro_eth80.npz',
    groupT=groupT,
    contrastedT=contrastedT,
    individualRank=individualRank,
    commonRank=commonRank,
    random_state=random_state
)

# %%
from PIL import Image

nframe = 25
nobj = 71

def get_image(tensor, nobj, nframe):
    image = tensor[nobj, :, nframe, :]
    image = image - image.min()
    image = image / image.max()
    image = reshape(image, [32, 32, 3])
    image *= 255.
    return image.astype(np.uint8)

image = get_image(data, nobj, nframe)
plt.imshow(image)
Image.fromarray(image).save('original.jpg')
plt.show()
image = get_image(groupT, nobj, nframe)
plt.imshow(image)
Image.fromarray(image).save('glro_common.jpg')
plt.show()
image = get_image(contrastedT, nobj, nframe)
plt.imshow(image)
Image.fromarray(image).save('glro_individual.jpg')
plt.show()
